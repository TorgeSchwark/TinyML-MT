# %% [markdown]
# Id in Image corresponds to the annotation "id"
# at the bottom the categories are listed having "ids" for each category

# %% [markdown]
# ## Global Variables

# %%
dataset_name = "MIT-Dataset" # CHANGE

dataset_path = "../MIT-Dataset/images" # CHANGE
dataset_labels = "../MIT-Dataset/annotations/"

# Source Dataset Paths
id_path = "../Dataset/id.txt"
prices_path = "Dataset/prices.txt"
destination = "Dataset/MIT-Dataset"
train = "D2S_training.json"

# %% [markdown]
# ## Extract next ID and Lable count

# %%
with open(id_path, 'r') as f:
    lines = f.readlines()
    id_count = int(lines[0].split()[1]) + 1
    label_count = int(lines[1].split()[1]) + 1

print("Id count: ", id_count)
print("Label count: ", label_count)
# Out:
# Id count:  27549
# Label count:  39

# %% [markdown]
# ### taking a look at categories:

# %%
import json
import os
from PIL import Image, ImageDraw, ImageFont

def extract_unique_categories(annotation_path):
    with open(annotation_path, 'r') as f:
        coco_data = json.load(f)
    
    # Extrahiere Kategorien und Superkategorien
    categories = coco_data.get("categories", [])
    category_labels = {category["name"]: category["id"] for category in categories}
    supercategory_labels = {category["supercategory"]: category["id"] for category in categories}
    
    return category_labels, supercategory_labels, coco_data

def find_image_for_supercategory(coco_data, supercategory_name, dataset_path):
    """
    Finde ein Bild, das eine Kategorie aus der angegebenen Superkategorie enthält.
    """
    # Alle Kategorien, die zur Superkategorie gehören
    categories = [
        cat["id"] for cat in coco_data["categories"] 
        if cat["supercategory"] == supercategory_name
    ]
    
    # Finde die erste Annotation, die eine dieser Kategorien hat
    for annotation in coco_data["annotations"]:
        if annotation["category_id"] in categories:
            # Finde das zugehörige Bild
            image_id = annotation["image_id"]
            for image in coco_data["images"]:
                if image["id"] == image_id:
                    return os.path.join(dataset_path, image["file_name"]), annotation["category_id"]

    return None, None

def display_image_with_supercategory(image_path, supercategory_name):
    """
    Öffne ein Bild und schreibe die Superkategorie darüber.
    """
    image = Image.open(image_path)
    draw = ImageDraw.Draw(image)
    
    # Passe die Schriftart an (oder verwende den Standard)
    try:
        font = ImageFont.truetype("arial.ttf", 20)
    except IOError:
        font = ImageFont.load_default()  # Verwende Standardschrift, wenn die angegebene Schrift fehlt
    
    # Schreibe die Superkategorie oben ins Bild
    text = f"Supercategory: {supercategory_name}"
    text_bbox = draw.textbbox((0, 0), text, font=font)
    text_width, text_height = text_bbox[2] - text_bbox[0], text_bbox[3] - text_bbox[1]
    
    # Zeichne einen Hintergrund für den Text
    draw.rectangle(((0, 0), (text_width + 10, text_height + 10)), fill="black")
    draw.text((5, 5), text, fill="white", font=font)
    
    # Bild anzeigen
    image.show()

categories = set()
supercategories = set()

for annons in os.listdir(dataset_labels):
    annotation_path = os.path.join(dataset_labels, annons)
    
    categories_temp, supercategories_temp, coco_data = extract_unique_categories(annotation_path)
    categories.update(categories_temp)  # Setze die neuen Kategorien ohne Duplikate
    supercategories.update(supercategories_temp)  # Setze die neuen Superkategorien ohne Duplikate

# Konvertiere zurück in Listen, falls notwendig
categories = list(categories)
supercategories = list(supercategories)

print(categories)
print(supercategories)

#Für jede Superkategorie ein Bild anzeigen
for supercategory_name in supercategories:
    image_path, category_id = find_image_for_supercategory(coco_data, supercategory_name, dataset_path)
    if image_path:
        print(f"Zeige Bild für Superkategorie: {supercategory_name} (Kategorie-ID: {category_id})")
        display_image_with_supercategory(image_path, supercategory_name)
    else:
        print(f"Kein Bild gefunden für Superkategorie: {supercategory_name}")
# Out:
# ['gepa_bio_und_fair_pfefferminztee', 'roma_vine_tomatoes', 'adelholzener_gourmet_mineralwasser_02', 'franken_tafelreiniger', 'douwe_egberts_professional_ground_coffee', 'grapes_green_sugraone_seedless', 'kiwi', 'salad_iceberg', 'corny_nussvoll_single', 'avocado', 'zucchini', 'ethiquable_gruener_tee_ceylon', 'koelln_muesli_fruechte', 'gepa_bio_und_fair_fencheltee', 'cucumber', 'augustiner_weissbier_05', 'apple_granny_smith', 'corny_schoko_banane', 'gepa_bio_und_fair_rooibostee', 'apple_braeburn_bundle', 'vine_tomatoes', 'clementine', 'dr_oetker_vitalis_knuspermuesli_klassisch', 'oranges', 'augustiner_lagerbraeu_hell_05', 'gepa_bio_und_fair_kraeuterteemischung', 'apple_red_boskoop', 'pasta_reggia_fusilli', 'caona_cocoa', 'tegernseer_hell_03', 'grapes_sweet_celebration_seedless', 'cafe_wunderbar_espresso', 'corn_salad', 'corny_nussvoll', 'lettuce', 'cocoba_cocoa', 'adelholzener_alpenquelle_naturell_075', 'pasta_reggia_elicoidali', 'adelholzener_classic_naturell_02', 'banana_bundle', 'gepa_bio_und_fair_kamillentee', 'gepa_italienischer_bio_espresso', 'clementine_single', 'carrot', 'apple_golden_delicious', 'rocket', 'orange_single', 'pasta_reggia_spaghetti', 'suntory_gokuri_lemonade', 'koelln_muesli_schoko', 'pelikan_tintenpatrone_canon', 'gepa_bio_caffe_crema', 'adelholzener_classic_bio_apfelschorle_02', 'corny_schoko_banane_single', 'coca_cola_light_05', 'banana_single', 'coca_cola_05', 'kilimanjaro_tea_earl_grey', 'pear', 'adelholzener_alpenquelle_classic_075']
# ['carrots', 'orange citrus', 'bananas', 'cereals', 'canned soft drink', 'tea', 'water', 'cucumbers', 'pasta', 'zucchinis', 'apple spritzer', 'pears', 'apples', 'foil', 'cardboard tray', 'nets', 'coca cola', 'blue glass', 'plastic tray', 'avocados', 'ink cartridge', 'textured packaging', 'kiwis', 'packaged cereal bars', 'board eraser', 'brown glass', 'salad']
# Zeige Bild für Superkategorie: carrots (Kategorie-ID: 53)
# Zeige Bild für Superkategorie: orange citrus (Kategorie-ID: 33)
# Zeige Bild für Superkategorie: bananas (Kategorie-ID: 31)
# Zeige Bild für Superkategorie: cereals (Kategorie-ID: 17)
# Zeige Bild für Superkategorie: canned soft drink (Kategorie-ID: 10)
# Zeige Bild für Superkategorie: tea (Kategorie-ID: 50)
# Kein Bild gefunden für Superkategorie: water
# Kein Bild gefunden für Superkategorie: cucumbers
# Zeige Bild für Superkategorie: pasta (Kategorie-ID: 42)
# Zeige Bild für Superkategorie: zucchinis (Kategorie-ID: 60)
# Zeige Bild für Superkategorie: apple spritzer (Kategorie-ID: 3)
# Kein Bild gefunden für Superkategorie: pears
# Zeige Bild für Superkategorie: apples (Kategorie-ID: 28)
# Zeige Bild für Superkategorie: foil (Kategorie-ID: 59)
# Zeige Bild für Superkategorie: cardboard tray (Kategorie-ID: 57)
# Zeige Bild für Superkategorie: nets (Kategorie-ID: 32)
# Zeige Bild für Superkategorie: coca cola (Kategorie-ID: 8)
# Zeige Bild für Superkategorie: blue glass (Kategorie-ID: 5)
# Zeige Bild für Superkategorie: plastic tray (Kategorie-ID: 58)
# Kein Bild gefunden für Superkategorie: avocados
# Zeige Bild für Superkategorie: ink cartridge (Kategorie-ID: 44)
# Zeige Bild für Superkategorie: textured packaging (Kategorie-ID: 15)
# Zeige Bild für Superkategorie: kiwis (Kategorie-ID: 36)
# Zeige Bild für Superkategorie: packaged cereal bars (Kategorie-ID: 12)
# Zeige Bild für Superkategorie: board eraser (Kategorie-ID: 43)
# Zeige Bild für Superkategorie: brown glass (Kategorie-ID: 11)
# Kein Bild gefunden für Superkategorie: salad

# %% [markdown]
# look at subcategories of unclear super categories

# %%
import json
import os
from PIL import Image, ImageDraw, ImageFont

def find_unwanted_subcategories(annotation_path, wanted_super_categories):
    with open(annotation_path, 'r') as f:
        coco_data = json.load(f)
    
    categories = coco_data.get("categories", [])
    unwanted_subcategories = {}
    
    for category in categories:
        supercategory_name = category["supercategory"]
        category_name = category["name"]
        category_id = category["id"]
        
        if supercategory_name not in wanted_super_categories:
            if supercategory_name not in unwanted_subcategories:
                unwanted_subcategories[supercategory_name] = []
            unwanted_subcategories[supercategory_name].append({"name": category_name, "id": category_id})
    
    return unwanted_subcategories

def display_images_with_subcategories(annotation_path, dataset_path, unwanted_subcategories):
    with open(annotation_path, 'r') as f:
        coco_data = json.load(f)
    
    annotations = coco_data.get("annotations", [])
    images = coco_data.get("images", [])
    
    # Map Image IDs to file names
    image_id_to_filename = {img["id"]: img["file_name"] for img in images}
    
    for supercategory, subcategories in unwanted_subcategories.items():
        for subcategory in subcategories:
            subcategory_name = subcategory["name"]
            subcategory_id = subcategory["id"]
            
            # Finde eine Annotation für diese Subkategorie
            for annotation in annotations:
                if annotation["category_id"] == subcategory_id:
                    image_id = annotation["image_id"]
                    image_file = image_id_to_filename.get(image_id)
                    
                    if image_file:
                        image_path = os.path.join(dataset_path, image_file)
                        
                        # Öffne das Bild
                        image = Image.open(image_path)
                        draw = ImageDraw.Draw(image)
                        
                        # Schrift für die Beschriftung (falls vorhanden, sonst Standard)
                        font = ImageFont.load_default()
                        
                        # Schreibe die Subkategorie auf das Bild
                        text = f"Subcategory: {subcategory_name}"
                        text_size = draw.textbbox((0, 0), text, font=font)
                        draw.rectangle([text_size[0], text_size[1], text_size[2] + 10, text_size[3] + 10], fill="black")
                        draw.text((5, 5), text, fill="white", font=font)
                        
                        # Zeige das Bild an
                        image.show()
                        break  # Nur ein Bild pro Subkategorie anzeigen

# Beispiel-Aufruf
wanted_super_categories = ["tea", "cereals", "packaged cereal bars", "salad", "pasta", "canned soft drink",
                           "board eraser", "pears", "kiwis", "bananas", "avocados", "orange citrus", "apples",
                           "zucchinis", "cucumbers", "carrots", "salad", "apple spritzer", "coca cola", "brown glass", "ink cartridge"]

merge_subcategories = {"water_small": ["adelholzener_gourmet_mineralwasser_02", "adelholzener_classic_naturell_02"], "water_big" : ["adelholzener_alpenquelle_naturell_075", "adelholzener_alpenquelle_classic_075"], "tomatos": ["vine_tomatoes","roma_vine_tomatoes"], 
                       "apple bundle": ["apple_braeburn_bundle "], "orange bundle": ["oranges", "clementine"], "grapes bundle" :["grapes_green_sugraone_seedless", "grapes_sweet_celebration_seedless"],
                       "salad": ["corn_salad", "rocket", "salad_iceberg"], "kaffee": ["gepa_bio_caffe_crema", "douwe_egberts_professional_ground_coffee", "cafe_wunderbar_espresso"], "lose Riegel": ["corny_schoko_banane_single", "corny_nussvoll_single"], "cacao": ["caona_cocoa", "cocoba_cocoa"]}

#TODO:: look at aple spritzer...

unwanted_subcategories = find_unwanted_subcategories(annotation_path, wanted_super_categories)
display_images_with_subcategories(annotation_path, dataset_path, unwanted_subcategories)

# Ausgabe der unerwünschten Subkategorien
for supercategory, subcategories in unwanted_subcategories.items():
    print(f"Supercategory: {supercategory}")
    for subcategory in subcategories:
        print(f"  - Subcategory: {subcategory['name']} (ID: {subcategory['id']})")
# Out:
# Supercategory: textured packaging
#   - Subcategory: caona_cocoa (ID: 19)
#   - Subcategory: cafe_wunderbar_espresso (ID: 21)
#   - Subcategory: gepa_italienischer_bio_espresso (ID: 24)
#   - Subcategory: douwe_egberts_professional_ground_coffee (ID: 22)
#   - Subcategory: corny_nussvoll_single (ID: 13)
#   - Subcategory: corny_schoko_banane_single (ID: 15)
#   - Subcategory: gepa_bio_caffe_crema (ID: 23)
#   - Subcategory: cocoba_cocoa (ID: 20)
# Supercategory: plastic tray
#   - Subcategory: grapes_green_sugraone_seedless (ID: 34)
#   - Subcategory: corn_salad (ID: 54)
#   - Subcategory: rocket (ID: 58)
#   - Subcategory: grapes_sweet_celebration_seedless (ID: 35)
# Supercategory: nets
#   - Subcategory: oranges (ID: 38)
#   - Subcategory: clementine (ID: 32)
# Supercategory: foil
#   - Subcategory: salad_iceberg (ID: 59)
# Supercategory: cardboard tray
#   - Subcategory: vine_tomatoes (ID: 56)
#   - Subcategory: apple_braeburn_bundle (ID: 25)
#   - Subcategory: roma_vine_tomatoes (ID: 57)
# Supercategory: water
#   - Subcategory: adelholzener_alpenquelle_classic_075 (ID: 1)
#   - Subcategory: adelholzener_alpenquelle_naturell_075 (ID: 2)
#   - Subcategory: adelholzener_classic_naturell_02 (ID: 4)
# Supercategory: blue glass
#   - Subcategory: adelholzener_gourmet_mineralwasser_02 (ID: 5)

# %%
import json

def map_subcategories(annotation_path, wanted_super_categories, merge_subcategories):
    with open(annotation_path, 'r') as f:
        coco_data = json.load(f)

    categories = coco_data.get("categories", [])
    subcategory_to_supercategory = {}
    not_covered_subcategories = []

    for category in categories:
        category_name = category["name"]
        supercategory_name = category["supercategory"]
        
        # Prüfen, ob die Subkategorie in wanted_super_categories enthalten ist
        if supercategory_name in wanted_super_categories:
            subcategory_to_supercategory[category_name] = supercategory_name
        # Prüfen, ob die Subkategorie in merge_subcategories enthalten ist
        elif any(category_name in subcategories for subcategories in merge_subcategories.values()):
            # Finde die passende Superkategorie in merge_subcategories
            for merged_supercategory, subcategories in merge_subcategories.items():
                if category_name in subcategories:
                    subcategory_to_supercategory[category_name] = merged_supercategory
                    break
        else:
            # Subkategorie ist nicht abgedeckt
            not_covered_subcategories.append(category_name)

    return subcategory_to_supercategory, not_covered_subcategories

# Beispiel-Aufruf
wanted_super_categories = [
    "tea", "cereals", "packaged cereal bars", "salad", "pasta", "canned soft drink",
    "board eraser", "pears", "kiwis", "bananas", "avocados", "orange citrus", "apples",
    "zucchinis", "cucumbers", "carrots", "salad", "apple spritzer", "coca cola", "brown glass", "ink cartridge"
]
merge_subcategories = {
    "water_small": ["adelholzener_gourmet_mineralwasser_02", "adelholzener_classic_naturell_02"],
    "water_big": ["adelholzener_alpenquelle_naturell_075", "adelholzener_alpenquelle_classic_075"],
    "tomatos": ["vine_tomatoes", "roma_vine_tomatoes"],
    "apple bundle": ["apple_braeburn_bundle"],
    "orange bundle": ["oranges", "clementine"],
    "grapes bundle": ["grapes_green_sugraone_seedless", "grapes_sweet_celebration_seedless"],
    "salad": ["corn_salad", "rocket", "salad_iceberg"],
    "kaffee": ["gepa_bio_caffe_crema", "douwe_egberts_professional_ground_coffee", "cafe_wunderbar_espresso", "gepa_italienischer_bio_espresso"],
    "lose Riegel": ["corny_schoko_banane_single", "corny_nussvoll_single"],
    "cacao": ["caona_cocoa", "cocoba_cocoa"]
}


subcategory_to_supercategory, not_covered_subcategories = map_subcategories(
    annotation_path, wanted_super_categories, merge_subcategories
)

# Ausgabe: Subkategorie -> Superkategorie
print("Subcategory to Supercategory Mapping:")
for subcategory, supercategory in subcategory_to_supercategory.items():
    print(f"{subcategory} -> {supercategory}")

# Ausgabe: Nicht abgedeckte Subkategorien
print("\nNot Covered Subcategories:")
for subcategory in not_covered_subcategories:
    print(subcategory)
# Out:
# Subcategory to Supercategory Mapping:
# gepa_bio_und_fair_fencheltee -> tea
# gepa_bio_und_fair_kraeuterteemischung -> tea
# gepa_bio_und_fair_kamillentee -> tea
# ethiquable_gruener_tee_ceylon -> tea
# gepa_bio_und_fair_pfefferminztee -> tea
# gepa_bio_und_fair_rooibostee -> tea
# kilimanjaro_tea_earl_grey -> tea
# koelln_muesli_fruechte -> cereals
# koelln_muesli_schoko -> cereals
# dr_oetker_vitalis_knuspermuesli_klassisch -> cereals
# corny_nussvoll -> packaged cereal bars
# corny_schoko_banane -> packaged cereal bars
# pelikan_tintenpatrone_canon -> ink cartridge
# lettuce -> salad
# carrot -> carrots
# cucumber -> cucumbers
# zucchini -> zucchinis
# apple_golden_delicious -> apples
# apple_granny_smith -> apples
# apple_red_boskoop -> apples
# orange_single -> orange citrus
# clementine_single -> orange citrus
# avocado -> avocados
# banana_bundle -> bananas
# banana_single -> bananas
# kiwi -> kiwis
# pear -> pears
# franken_tafelreiniger -> board eraser
# suntory_gokuri_lemonade -> canned soft drink
# pasta_reggia_elicoidali -> pasta
# pasta_reggia_fusilli -> pasta
# pasta_reggia_spaghetti -> pasta
# caona_cocoa -> cacao
# cafe_wunderbar_espresso -> kaffee
# gepa_italienischer_bio_espresso -> kaffee
# douwe_egberts_professional_ground_coffee -> kaffee
# corny_nussvoll_single -> lose Riegel
# corny_schoko_banane_single -> lose Riegel
# gepa_bio_caffe_crema -> kaffee
# cocoba_cocoa -> cacao
# grapes_green_sugraone_seedless -> grapes bundle
# corn_salad -> salad
# rocket -> salad
# grapes_sweet_celebration_seedless -> grapes bundle
# oranges -> orange bundle
# clementine -> orange bundle
# salad_iceberg -> salad
# vine_tomatoes -> tomatos
# apple_braeburn_bundle -> apple bundle
# roma_vine_tomatoes -> tomatos
# adelholzener_alpenquelle_classic_075 -> water_big
# adelholzener_alpenquelle_naturell_075 -> water_big
# adelholzener_classic_naturell_02 -> water_small
# coca_cola_05 -> coca cola
# coca_cola_light_05 -> coca cola
# adelholzener_classic_bio_apfelschorle_02 -> apple spritzer
# augustiner_lagerbraeu_hell_05 -> brown glass
# augustiner_weissbier_05 -> brown glass
# tegernseer_hell_03 -> brown glass
# adelholzener_gourmet_mineralwasser_02 -> water_small
#
# Not Covered Subcategories:

# %%
wanted_super_categories = [
    "tea", "cereals", "packaged cereal bars", "salad", "pasta", "canned soft drink",
    "board eraser", "pears", "kiwis", "bananas", "avocados", "orange citrus", "apples",
    "zucchinis", "cucumbers", "carrots", "apple spritzer", "coca cola", "brown glass", "ink cartridge"
]

merge_subcategories = {
    "water_small": ["adelholzener_gourmet_mineralwasser_02", "adelholzener_classic_naturell_02"],
    "water_big": ["adelholzener_alpenquelle_naturell_075", "adelholzener_alpenquelle_classic_075"],
    "tomatos": ["vine_tomatoes", "roma_vine_tomatoes"],
    "apple bundle": ["apple_braeburn_bundle"],
    "orange bundle": ["oranges", "clementine"],
    "grapes bundle": ["grapes_green_sugraone_seedless", "grapes_sweet_celebration_seedless"],
    "salad": ["corn_salad", "rocket", "salad_iceberg"],
    "coffee": ["gepa_bio_caffe_crema", "douwe_egberts_professional_ground_coffee", "cafe_wunderbar_espresso", "gepa_italienischer_bio_espresso"],
    "lose Riegel": ["corny_schoko_banane_single", "corny_nussvoll_single"],
    "cacao": ["caona_cocoa", "cocoba_cocoa"]
}

existing = {"tea": 26, "pasta": 9, "bananas": 4, "avocados": 3, "apples": 1, "coffee": 13}

labels = []
for label in wanted_super_categories:
    labels.append(label)
for key in merge_subcategories:
    labels.append(key)
0.

label_count = 39
label_to_price = {}
num_to_label = {}
i = 0
for label in labels:
    if not label in existing:
        new_label = input(f"Enter the new label for {label} (Skip): ")
        price = float(input(f"Enter the price for {label}: "))
        label_to_price[label_count] = [new_label,price]
        num_to_label[i] = label_count
        label_count += 1
        print("Added label and price:", new_label, price)
        i += 1

print(label_to_price)

label_to_price_with_existing = {**label_to_price, **existing}
print(label_to_price_with_existing)
price_id_dict = {39: ['cereals', 2.49], 40: ['packaged cereal bars', 1.99], 41: ['salad', 2.29], 42: ['canned soft drink', 0.99], 
        43: ['board eraser', 4.99], 44 : ['pears', 0.67], 45: ['kiwis', 0.29], 46: ['orange citrus', 0.29], 47: ['zucchinis', 1.11],
        48: ['cucumbers', 1.11], 49: ['carrots', 0.19], 50: ['apple spritzer', 1.19], 51: ['coca cola', 1.10], 52: ['brown glass', 1.29],
        53: ['ink cartridge', 4.99], 54: ['water_small', 0.79], 55: ['water_big', 1.19], 56: ['tomatos', 1.49], 57: ['apple bundle', 1.19],
        58: ['orange bundle', 1.29], 59: ['grapes bundle', 1.49], 60: ['lose Riegel', 0.69], 61: ['cacao', 4.99],
        26: ['tea', 2.35], 9: ['pasta', 2.69], 3 : ['avocados', 1.29],
        4: ['bananas', 0.46], 1: ['apples',  0.6], 13: ['coffee', 7.99]}
# Out:
# Added label and price:  2.49
# Added label and price:  1.99
# Added label and price:  2.29
# Added label and price:  0.99
# Added label and price:  4.0
# Added label and price:  0.67
# Added label and price:  0.79
# Added label and price: banana 0.46
# Added label and price:  0.8
# Added label and price:  1.11
# Added label and price:  1.11
# Added label and price:  0.15
# Added label and price:  1.49
# Added label and price:  1.19
# Added label and price:  1.19
# Added label and price:  1.7
# Added label and price:  9.99
# Added label and price:  0.8
# Added label and price:  1.29
# Added label and price:  2.5
# Added label and price:  1.2
# Added label and price:  1.2
# Added label and price:  1.99
# Added label and price:  1.49
# Added label and price:  0.69
# Added label and price:  5.99
# {39: ['', 2.49], 40: ['', 1.99], 41: ['', 2.29], 42: ['', 0.99], 43: ['', 4.0], 44: ['', 0.67], 45: ['', 0.79], 46: ['banana', 0.46], 47: ['', 0.8], 48: ['', 1.11], 49: ['', 1.11], 50: ['', 0.15], 51: ['', 1.49], 52: ['', 1.19], 53: ['', 1.19], 54: ['', 1.7], 55: ['', 9.99], 56: ['', 0.8], 57: ['', 1.29], 58: ['', 2.5], 59: ['', 1.2], 60: ['', 1.2], 61: ['', 1.99], 62: ['', 1.49], 63: ['', 0.69], 64: ['', 5.99]}
# {39: ['', 2.49], 40: ['', 1.99], 41: ['', 2.29], 42: ['', 0.99], 43: ['', 4.0], 44: ['', 0.67], 45: ['', 0.79], 46: ['banana', 0.46], 47: ['', 0.8], 48: ['', 1.11], 49: ['', 1.11], 50: ['', 0.15], 51: ['', 1.49], 52: ['', 1.19], 53: ['', 1.19], 54: ['', 1.7], 55: ['', 9.99], 56: ['', 0.8], 57: ['', 1.29], 58: ['', 2.5], 59: ['', 1.2], 60: ['', 1.2], 61: ['', 1.99], 62: ['', 1.49], 63: ['', 0.69], 64: ['', 5.99], 'tea': 26, 'pasta': 9, 'banana': 4, 'avocados': 3, 'apples': 1, 'coffee': 13}

# %%
wanted_super_categories = [
    "tea", "cereals", "packaged cereal bars", "salad", "pasta", "canned soft drink",
    "board eraser", "pears", "kiwis", "bananas", "avocados", "orange citrus", "apples",
    "zucchinis", "cucumbers", "carrots", "apple spritzer", "coca cola", "brown glass", "ink cartridge"
]

merge_subcategories = {
    "water_small": ["adelholzener_gourmet_mineralwasser_02", "adelholzener_classic_naturell_02"],
    "water_big": ["adelholzener_alpenquelle_naturell_075", "adelholzener_alpenquelle_classic_075"],
    "tomatos": ["vine_tomatoes", "roma_vine_tomatoes"],
    "apple bundle": ["apple_braeburn_bundle"],
    "orange bundle": ["oranges", "clementine"],
    "grapes bundle": ["grapes_green_sugraone_seedless", "grapes_sweet_celebration_seedless"],
    "salad": ["corn_salad", "rocket", "salad_iceberg"],
    "coffee": ["gepa_bio_caffe_crema", "douwe_egberts_professional_ground_coffee", "cafe_wunderbar_espresso", "gepa_italienischer_bio_espresso"],
    "lose Riegel": ["corny_schoko_banane_single", "corny_nussvoll_single"],
    "cacao": ["caona_cocoa", "cocoba_cocoa"]
}

price_id_dict = {39: ['cereals', 2.49], 40: ['packaged cereal bars', 1.99], 41: ['salad', 2.29], 42: ['canned soft drink', 0.99], 
        43: ['board eraser', 4.99], 44 : ['pears', 0.67], 45: ['kiwis', 0.29], 46: ['orange citrus', 0.29], 47: ['zucchinis', 1.11],
        48: ['cucumbers', 1.11], 49: ['carrots', 0.19], 50: ['apple spritzer', 1.19], 51: ['coca cola', 1.10], 52: ['brown glass', 1.29],
        53: ['ink cartridge', 4.99], 54: ['water_small', 0.79], 55: ['water_big', 1.19], 56: ['tomatos', 1.49], 57: ['apple bundle', 1.19],
        58: ['orange bundle', 1.29], 59: ['grapes bundle', 1.49], 60: ['lose Riegel', 0.69], 61: ['cacao', 4.99],
        26: ['tea', 2.35], 9: ['pasta', 2.69], 3 : ['avocados', 1.29],
        4: ['bananas', 0.46], 1: ['apples',  0.6], 13: ['coffee', 7.99]}


import os
import json
import shutil

# Pfade
dataset_path = "../MIT-Dataset/images/"
destination = "../Dataset/MIT-Dataset/"
dataset_labels = "../MIT-Dataset/annotations/"
id_path = "../Dataset/id.txt"

desired_files = ["D2S_test_info.json", "D2S_augmented.json", "D2S_training.json", "D2S_validation.json"]

def process_annotations():
    image_id_counter = 4044

    # Hole alle Bilder im Dataset-Label-Verzeichnis
    for annotation_file in desired_files:
        anotation_path = os.path.join(dataset_labels, annotation_file)
        with open(anotation_path, 'r') as f:
                coco_data = json.load(f)

        for image_coco in coco_data.get("images", []):
            imgage_id = image_coco["id"]

            image_annotations = []

            # Durchsuche die Annotations und finde die relevanten für das aktuelle Bild
            for annotation in coco_data.get("annotations", []):
                if annotation["image_id"] == int(imgage_id):  # Extrahiere die Bild-ID
                    image_annotations.append(annotation)

            # Wenn Annotationen vorhanden sind, bearbeite das Bild
            if image_annotations:
                objects_count = {}
                total_price = 0.0

                # Gehe durch alle gefundenen Annotationen
                for annotation in image_annotations:
                    category_id = annotation["category_id"]
                    category_name = None
                    supercategory_name = None

                    # Finde den entsprechenden Category-Namen und Supercategory
                    for category in coco_data["categories"]:
                        if category["id"] == category_id:
                            supercategory_name = category["supercategory"]
                            category_name = category["name"]
                            break
                    
                    # Bestimme den Namen basierend auf den supercategories und merge_subcategories
                    if supercategory_name in wanted_super_categories:
                        object_name = supercategory_name
                    else:
                        object_name = None
                        for merge_key, subcategories in merge_subcategories.items():
                            if category_name in subcategories:
                                object_name = merge_key
                                break
                    
                    # Falls ein passender Name gefunden wurde
                    if object_name:
                        for key, value in price_id_dict.items():
                            if value[0] == object_name:
                                object_id = key
                                break
                        if object_id not in objects_count:
                            objects_count[object_id] = 0
                        objects_count[object_id] += 1

                        # Berechne den Gesamtpreis
                        if category_id in price_id_dict:
                            total_price += price_id_dict[category_id][1]
                    else:
                        print("Found new object super:", supercategory_name, "sub", category_name)

                # Formatierte Bild-ID mit führenden Nullen
                formatted_image_id = f"image_{str(image_id_counter)}"
                new_image_filename = f"{formatted_image_id}.jpg"
                image_filename = f"D2S_{str(imgage_id).zfill(6)}.jpg"

                # Kopiere das Bild
                image_path = os.path.join(dataset_path, image_filename)
                new_image_path = os.path.join(destination, new_image_filename)
                shutil.copy(image_path, new_image_path)

                # Erstelle die TXT-Datei mit den Objecten und Preisen
                txt_filename = f"{formatted_image_id}.txt"
                txt_file_path = os.path.join(destination, txt_filename)
                with open(txt_file_path, 'w') as f:
                    f.write(f"Objects: {str(objects_count)}\n")
                    f.write(f"Total Price: {total_price:.2f}")

                image_id_counter += 1
                print(f"Bild {image_filename} verarbeitet und nach {new_image_filename} verschoben.")
    with open(id_path, "r") as f:
        lines = f.readlines()

    if lines:
        lines[0] = "current_id: " + str(image_id_counter) + "\n"
    else:
        lines.append("current_id: " + str(image_id_counter) + "\n")

    with open(id_path, "w") as f:
        f.writelines(lines)

    

# Beispiel-Aufruf
process_annotations()
# Out:
# Bild D2S_99000000.jpg verarbeitet und nach image_3174.jpg verschoben.
# Bild D2S_99000001.jpg verarbeitet und nach image_3175.jpg verschoben.
# Bild D2S_99000002.jpg verarbeitet und nach image_3176.jpg verschoben.
# Bild D2S_99000003.jpg verarbeitet und nach image_3177.jpg verschoben.
# Bild D2S_99000004.jpg verarbeitet und nach image_3178.jpg verschoben.
# Bild D2S_99000005.jpg verarbeitet und nach image_3179.jpg verschoben.
# Bild D2S_99000006.jpg verarbeitet und nach image_3180.jpg verschoben.
# Bild D2S_99000007.jpg verarbeitet und nach image_3181.jpg verschoben.
# Bild D2S_99000008.jpg verarbeitet und nach image_3182.jpg verschoben.
# Bild D2S_99000009.jpg verarbeitet und nach image_3183.jpg verschoben.
# Bild D2S_99000010.jpg verarbeitet und nach image_3184.jpg verschoben.
# Bild D2S_99000011.jpg verarbeitet und nach image_3185.jpg verschoben.
# Bild D2S_99000012.jpg verarbeitet und nach image_3186.jpg verschoben.
# Bild D2S_99000013.jpg verarbeitet und nach image_3187.jpg verschoben.
# Bild D2S_99000014.jpg verarbeitet und nach image_3188.jpg verschoben.
# Bild D2S_99000015.jpg verarbeitet und nach image_3189.jpg verschoben.
# Bild D2S_99000016.jpg verarbeitet und nach image_3190.jpg verschoben.
# Bild D2S_99000017.jpg verarbeitet und nach image_3191.jpg verschoben.
# Bild D2S_99000018.jpg verarbeitet und nach image_3192.jpg verschoben.
# Bild D2S_99000019.jpg verarbeitet und nach image_3193.jpg verschoben.
# Bild D2S_99000020.jpg verarbeitet und nach image_3194.jpg verschoben.
# Bild D2S_99000021.jpg verarbeitet und nach image_3195.jpg verschoben.
# Bild D2S_99000022.jpg verarbeitet und nach image_3196.jpg verschoben.
# Bild D2S_99000023.jpg verarbeitet und nach image_3197.jpg verschoben.
# Bild D2S_99000024.jpg verarbeitet und nach image_3198.jpg verschoben.
# Bild D2S_99000025.jpg verarbeitet und nach image_3199.jpg verschoben.
# Bild D2S_99000026.jpg verarbeitet und nach image_3200.jpg verschoben.
# Bild D2S_99000027.jpg verarbeitet und nach image_3201.jpg verschoben.
# Bild D2S_99000028.jpg verarbeitet und nach image_3202.jpg verschoben.
# Bild D2S_99000029.jpg verarbeitet und nach image_3203.jpg verschoben.
# Bild D2S_99000030.jpg verarbeitet und nach image_3204.jpg verschoben.
# Bild D2S_99000031.jpg verarbeitet und nach image_3205.jpg verschoben.
# Bild D2S_99000032.jpg verarbeitet und nach image_3206.jpg verschoben.
# Bild D2S_99000033.jpg verarbeitet und nach image_3207.jpg verschoben.
# Bild D2S_99000034.jpg verarbeitet und nach image_3208.jpg verschoben.
# Bild D2S_99000035.jpg verarbeitet und nach image_3209.jpg verschoben.
# Bild D2S_99000036.jpg verarbeitet und nach image_3210.jpg verschoben.
# Bild D2S_99000037.jpg verarbeitet und nach image_3211.jpg verschoben.
# Bild D2S_99000038.jpg verarbeitet und nach image_3212.jpg verschoben.
# Bild D2S_99000039.jpg verarbeitet und nach image_3213.jpg verschoben.
# Bild D2S_99000040.jpg verarbeitet und nach image_3214.jpg verschoben.
# Bild D2S_99000041.jpg verarbeitet und nach image_3215.jpg verschoben.
# Bild D2S_99000042.jpg verarbeitet und nach image_3216.jpg verschoben.
# Bild D2S_99000043.jpg verarbeitet und nach image_3217.jpg verschoben.
# Bild D2S_99000044.jpg verarbeitet und nach image_3218.jpg verschoben.
# Bild D2S_99000045.jpg verarbeitet und nach image_3219.jpg verschoben.
# Bild D2S_99000046.jpg verarbeitet und nach image_3220.jpg verschoben.
# Bild D2S_99000047.jpg verarbeitet und nach image_3221.jpg verschoben.
# Bild D2S_99000048.jpg verarbeitet und nach image_3222.jpg verschoben.
# Bild D2S_99000049.jpg verarbeitet und nach image_3223.jpg verschoben.
# Bild D2S_99000050.jpg verarbeitet und nach image_3224.jpg verschoben.
# Bild D2S_99000051.jpg verarbeitet und nach image_3225.jpg verschoben.
# Bild D2S_99000052.jpg verarbeitet und nach image_3226.jpg verschoben.
# Bild D2S_99000053.jpg verarbeitet und nach image_3227.jpg verschoben.
# Bild D2S_99000054.jpg verarbeitet und nach image_3228.jpg verschoben.
# Bild D2S_99000055.jpg verarbeitet und nach image_3229.jpg verschoben.
# Bild D2S_99000056.jpg verarbeitet und nach image_3230.jpg verschoben.
# Bild D2S_99000057.jpg verarbeitet und nach image_3231.jpg verschoben.
# Bild D2S_99000058.jpg verarbeitet und nach image_3232.jpg verschoben.
# Bild D2S_99000059.jpg verarbeitet und nach image_3233.jpg verschoben.
# Bild D2S_99000060.jpg verarbeitet und nach image_3234.jpg verschoben.
# Bild D2S_99000061.jpg verarbeitet und nach image_3235.jpg verschoben.
# Bild D2S_99000062.jpg verarbeitet und nach image_3236.jpg verschoben.
# Bild D2S_99000063.jpg verarbeitet und nach image_3237.jpg verschoben.
# Bild D2S_99000064.jpg verarbeitet und nach image_3238.jpg verschoben.
# Bild D2S_99000065.jpg verarbeitet und nach image_3239.jpg verschoben.
# Bild D2S_99000066.jpg verarbeitet und nach image_3240.jpg verschoben.
# Bild D2S_99000067.jpg verarbeitet und nach image_3241.jpg verschoben.
# Bild D2S_99000068.jpg verarbeitet und nach image_3242.jpg verschoben.
# Bild D2S_99000069.jpg verarbeitet und nach image_3243.jpg verschoben.
# Bild D2S_99000070.jpg verarbeitet und nach image_3244.jpg verschoben.
# Bild D2S_99000071.jpg verarbeitet und nach image_3245.jpg verschoben.
# Bild D2S_99000072.jpg verarbeitet und nach image_3246.jpg verschoben.
# Bild D2S_99000073.jpg verarbeitet und nach image_3247.jpg verschoben.
# Bild D2S_99000074.jpg verarbeitet und nach image_3248.jpg verschoben.
# Bild D2S_99000075.jpg verarbeitet und nach image_3249.jpg verschoben.
# Bild D2S_99000076.jpg verarbeitet und nach image_3250.jpg verschoben.
# Bild D2S_99000077.jpg verarbeitet und nach image_3251.jpg verschoben.
# Bild D2S_99000078.jpg verarbeitet und nach image_3252.jpg verschoben.
# Bild D2S_99000079.jpg verarbeitet und nach image_3253.jpg verschoben.
# Bild D2S_99000080.jpg verarbeitet und nach image_3254.jpg verschoben.
# Bild D2S_99000081.jpg verarbeitet und nach image_3255.jpg verschoben.
# Bild D2S_99000082.jpg verarbeitet und nach image_3256.jpg verschoben.
# Bild D2S_99000083.jpg verarbeitet und nach image_3257.jpg verschoben.
# Bild D2S_99000084.jpg verarbeitet und nach image_3258.jpg verschoben.
# Bild D2S_99000085.jpg verarbeitet und nach image_3259.jpg verschoben.
# Bild D2S_99000086.jpg verarbeitet und nach image_3260.jpg verschoben.
# Bild D2S_99000087.jpg verarbeitet und nach image_3261.jpg verschoben.
# Bild D2S_99000088.jpg verarbeitet und nach image_3262.jpg verschoben.
# Bild D2S_99000089.jpg verarbeitet und nach image_3263.jpg verschoben.
# Bild D2S_99000090.jpg verarbeitet und nach image_3264.jpg verschoben.
# Bild D2S_99000091.jpg verarbeitet und nach image_3265.jpg verschoben.
# Bild D2S_99000092.jpg verarbeitet und nach image_3266.jpg verschoben.
# Bild D2S_99000093.jpg verarbeitet und nach image_3267.jpg verschoben.
# Bild D2S_99000094.jpg verarbeitet und nach image_3268.jpg verschoben.
# Bild D2S_99000095.jpg verarbeitet und nach image_3269.jpg verschoben.
# Bild D2S_99000096.jpg verarbeitet und nach image_3270.jpg verschoben.
# Bild D2S_99000097.jpg verarbeitet und nach image_3271.jpg verschoben.
# Bild D2S_99000098.jpg verarbeitet und nach image_3272.jpg verschoben.
# Bild D2S_99000099.jpg verarbeitet und nach image_3273.jpg verschoben.
# Bild D2S_99000100.jpg verarbeitet und nach image_3274.jpg verschoben.
# Bild D2S_99000101.jpg verarbeitet und nach image_3275.jpg verschoben.
# Bild D2S_99000102.jpg verarbeitet und nach image_3276.jpg verschoben.
# Bild D2S_99000103.jpg verarbeitet und nach image_3277.jpg verschoben.
# Bild D2S_99000104.jpg verarbeitet und nach image_3278.jpg verschoben.
# Bild D2S_99000105.jpg verarbeitet und nach image_3279.jpg verschoben.
# Bild D2S_99000106.jpg verarbeitet und nach image_3280.jpg verschoben.
# Bild D2S_99000107.jpg verarbeitet und nach image_3281.jpg verschoben.
# Bild D2S_99000108.jpg verarbeitet und nach image_3282.jpg verschoben.
# Bild D2S_99000109.jpg verarbeitet und nach image_3283.jpg verschoben.
# Bild D2S_99000110.jpg verarbeitet und nach image_3284.jpg verschoben.
# Bild D2S_99000111.jpg verarbeitet und nach image_3285.jpg verschoben.
# Bild D2S_99000112.jpg verarbeitet und nach image_3286.jpg verschoben.
# Bild D2S_99000113.jpg verarbeitet und nach image_3287.jpg verschoben.
# Bild D2S_99000114.jpg verarbeitet und nach image_3288.jpg verschoben.
# Bild D2S_99000115.jpg verarbeitet und nach image_3289.jpg verschoben.
# Bild D2S_99000116.jpg verarbeitet und nach image_3290.jpg verschoben.
# Bild D2S_99000117.jpg verarbeitet und nach image_3291.jpg verschoben.
# Bild D2S_99000118.jpg verarbeitet und nach image_3292.jpg verschoben.
# Bild D2S_99000119.jpg verarbeitet und nach image_3293.jpg verschoben.
# Bild D2S_99000120.jpg verarbeitet und nach image_3294.jpg verschoben.
# Bild D2S_99000121.jpg verarbeitet und nach image_3295.jpg verschoben.
# Bild D2S_99000122.jpg verarbeitet und nach image_3296.jpg verschoben.
# Bild D2S_99000123.jpg verarbeitet und nach image_3297.jpg verschoben.
# Bild D2S_99000124.jpg verarbeitet und nach image_3298.jpg verschoben.
# Bild D2S_99000125.jpg verarbeitet und nach image_3299.jpg verschoben.
# Bild D2S_99000126.jpg verarbeitet und nach image_3300.jpg verschoben.
# Bild D2S_99000127.jpg verarbeitet und nach image_3301.jpg verschoben.
# Bild D2S_99000128.jpg verarbeitet und nach image_3302.jpg verschoben.
# Bild D2S_99000129.jpg verarbeitet und nach image_3303.jpg verschoben.
# Bild D2S_99000130.jpg verarbeitet und nach image_3304.jpg verschoben.
# Bild D2S_99000131.jpg verarbeitet und nach image_3305.jpg verschoben.
# Bild D2S_99000132.jpg verarbeitet und nach image_3306.jpg verschoben.
# Bild D2S_99000133.jpg verarbeitet und nach image_3307.jpg verschoben.
# Bild D2S_99000134.jpg verarbeitet und nach image_3308.jpg verschoben.
# Bild D2S_99000135.jpg verarbeitet und nach image_3309.jpg verschoben.
# Bild D2S_99000136.jpg verarbeitet und nach image_3310.jpg verschoben.
# Bild D2S_99000137.jpg verarbeitet und nach image_3311.jpg verschoben.
# Bild D2S_99000138.jpg verarbeitet und nach image_3312.jpg verschoben.
# Bild D2S_99000139.jpg verarbeitet und nach image_3313.jpg verschoben.
# Bild D2S_99000140.jpg verarbeitet und nach image_3314.jpg verschoben.
# Bild D2S_99000141.jpg verarbeitet und nach image_3315.jpg verschoben.
# Bild D2S_99000142.jpg verarbeitet und nach image_3316.jpg verschoben.
# Bild D2S_99000143.jpg verarbeitet und nach image_3317.jpg verschoben.
# Bild D2S_99000144.jpg verarbeitet und nach image_3318.jpg verschoben.
# Bild D2S_99000145.jpg verarbeitet und nach image_3319.jpg verschoben.
# Bild D2S_99000146.jpg verarbeitet und nach image_3320.jpg verschoben.
# Bild D2S_99000147.jpg verarbeitet und nach image_3321.jpg verschoben.
# Bild D2S_99000148.jpg verarbeitet und nach image_3322.jpg verschoben.
# Bild D2S_99000149.jpg verarbeitet und nach image_3323.jpg verschoben.
# Bild D2S_99000150.jpg verarbeitet und nach image_3324.jpg verschoben.
# Bild D2S_99000151.jpg verarbeitet und nach image_3325.jpg verschoben.
# Bild D2S_99000152.jpg verarbeitet und nach image_3326.jpg verschoben.
# Bild D2S_99000153.jpg verarbeitet und nach image_3327.jpg verschoben.
# Bild D2S_99000154.jpg verarbeitet und nach image_3328.jpg verschoben.
# Bild D2S_99000155.jpg verarbeitet und nach image_3329.jpg verschoben.
# Bild D2S_99000156.jpg verarbeitet und nach image_3330.jpg verschoben.
# Bild D2S_99000157.jpg verarbeitet und nach image_3331.jpg verschoben.
# Bild D2S_99000158.jpg verarbeitet und nach image_3332.jpg verschoben.
# Bild D2S_99000159.jpg verarbeitet und nach image_3333.jpg verschoben.
# Bild D2S_99000160.jpg verarbeitet und nach image_3334.jpg verschoben.
# Bild D2S_99000161.jpg verarbeitet und nach image_3335.jpg verschoben.
# Bild D2S_99000162.jpg verarbeitet und nach image_3336.jpg verschoben.
# Bild D2S_99000163.jpg verarbeitet und nach image_3337.jpg verschoben.
# Bild D2S_99000164.jpg verarbeitet und nach image_3338.jpg verschoben.
# Bild D2S_99000165.jpg verarbeitet und nach image_3339.jpg verschoben.
# Bild D2S_99000166.jpg verarbeitet und nach image_3340.jpg verschoben.
# Bild D2S_99000167.jpg verarbeitet und nach image_3341.jpg verschoben.
# Bild D2S_99000168.jpg verarbeitet und nach image_3342.jpg verschoben.
# Bild D2S_99000169.jpg verarbeitet und nach image_3343.jpg verschoben.
# Bild D2S_99000170.jpg verarbeitet und nach image_3344.jpg verschoben.
# Bild D2S_99000171.jpg verarbeitet und nach image_3345.jpg verschoben.
# Bild D2S_99000172.jpg verarbeitet und nach image_3346.jpg verschoben.
# Bild D2S_99000173.jpg verarbeitet und nach image_3347.jpg verschoben.
# Bild D2S_99000174.jpg verarbeitet und nach image_3348.jpg verschoben.
# Bild D2S_99000175.jpg verarbeitet und nach image_3349.jpg verschoben.
# Bild D2S_99000176.jpg verarbeitet und nach image_3350.jpg verschoben.
# Bild D2S_99000177.jpg verarbeitet und nach image_3351.jpg verschoben.
# Bild D2S_99000178.jpg verarbeitet und nach image_3352.jpg verschoben.
# Bild D2S_99000179.jpg verarbeitet und nach image_3353.jpg verschoben.
# Bild D2S_99000180.jpg verarbeitet und nach image_3354.jpg verschoben.
# Bild D2S_99000181.jpg verarbeitet und nach image_3355.jpg verschoben.
# Bild D2S_99000182.jpg verarbeitet und nach image_3356.jpg verschoben.
# Bild D2S_99000183.jpg verarbeitet und nach image_3357.jpg verschoben.
# Bild D2S_99000184.jpg verarbeitet und nach image_3358.jpg verschoben.
# Bild D2S_99000185.jpg verarbeitet und nach image_3359.jpg verschoben.
# Bild D2S_99000186.jpg verarbeitet und nach image_3360.jpg verschoben.
# Bild D2S_99000187.jpg verarbeitet und nach image_3361.jpg verschoben.
# Bild D2S_99000188.jpg verarbeitet und nach image_3362.jpg verschoben.
# Bild D2S_99000189.jpg verarbeitet und nach image_3363.jpg verschoben.
# Bild D2S_99000190.jpg verarbeitet und nach image_3364.jpg verschoben.
# Bild D2S_99000191.jpg verarbeitet und nach image_3365.jpg verschoben.
# Bild D2S_99000192.jpg verarbeitet und nach image_3366.jpg verschoben.
# Bild D2S_99000193.jpg verarbeitet und nach image_3367.jpg verschoben.
# Bild D2S_99000194.jpg verarbeitet und nach image_3368.jpg verschoben.
# Bild D2S_99000195.jpg verarbeitet und nach image_3369.jpg verschoben.
# Bild D2S_99000196.jpg verarbeitet und nach image_3370.jpg verschoben.
# Bild D2S_99000197.jpg verarbeitet und nach image_3371.jpg verschoben.
# Bild D2S_99000198.jpg verarbeitet und nach image_3372.jpg verschoben.
# Bild D2S_99000199.jpg verarbeitet und nach image_3373.jpg verschoben.
# Bild D2S_99000200.jpg verarbeitet und nach image_3374.jpg verschoben.
# Bild D2S_99000201.jpg verarbeitet und nach image_3375.jpg verschoben.
# Bild D2S_99000202.jpg verarbeitet und nach image_3376.jpg verschoben.
# Bild D2S_99000203.jpg verarbeitet und nach image_3377.jpg verschoben.
# Bild D2S_99000204.jpg verarbeitet und nach image_3378.jpg verschoben.
# Bild D2S_99000205.jpg verarbeitet und nach image_3379.jpg verschoben.
# Bild D2S_99000206.jpg verarbeitet und nach image_3380.jpg verschoben.
# Bild D2S_99000207.jpg verarbeitet und nach image_3381.jpg verschoben.
# Bild D2S_99000208.jpg verarbeitet und nach image_3382.jpg verschoben.
# Bild D2S_99000209.jpg verarbeitet und nach image_3383.jpg verschoben.
# Bild D2S_99000210.jpg verarbeitet und nach image_3384.jpg verschoben.
# Bild D2S_99000211.jpg verarbeitet und nach image_3385.jpg verschoben.
# Bild D2S_99000212.jpg verarbeitet und nach image_3386.jpg verschoben.
# Bild D2S_99000213.jpg verarbeitet und nach image_3387.jpg verschoben.
# Bild D2S_99000214.jpg verarbeitet und nach image_3388.jpg verschoben.
# Bild D2S_99000215.jpg verarbeitet und nach image_3389.jpg verschoben.
# Bild D2S_99000216.jpg verarbeitet und nach image_3390.jpg verschoben.
# Bild D2S_99000217.jpg verarbeitet und nach image_3391.jpg verschoben.
# Bild D2S_99000218.jpg verarbeitet und nach image_3392.jpg verschoben.
# Bild D2S_99000219.jpg verarbeitet und nach image_3393.jpg verschoben.
# Bild D2S_99000220.jpg verarbeitet und nach image_3394.jpg verschoben.
# Bild D2S_99000221.jpg verarbeitet und nach image_3395.jpg verschoben.
# Bild D2S_99000222.jpg verarbeitet und nach image_3396.jpg verschoben.
# Bild D2S_99000223.jpg verarbeitet und nach image_3397.jpg verschoben.
# Bild D2S_99000224.jpg verarbeitet und nach image_3398.jpg verschoben.
# Bild D2S_99000225.jpg verarbeitet und nach image_3399.jpg verschoben.
# Bild D2S_99000226.jpg verarbeitet und nach image_3400.jpg verschoben.
# Bild D2S_99000227.jpg verarbeitet und nach image_3401.jpg verschoben.
# Bild D2S_99000228.jpg verarbeitet und nach image_3402.jpg verschoben.
# Bild D2S_99000229.jpg verarbeitet und nach image_3403.jpg verschoben.
# Bild D2S_99000230.jpg verarbeitet und nach image_3404.jpg verschoben.
# Bild D2S_99000231.jpg verarbeitet und nach image_3405.jpg verschoben.
# Bild D2S_99000232.jpg verarbeitet und nach image_3406.jpg verschoben.
# Bild D2S_99000233.jpg verarbeitet und nach image_3407.jpg verschoben.
# Bild D2S_99000234.jpg verarbeitet und nach image_3408.jpg verschoben.
# Bild D2S_99000235.jpg verarbeitet und nach image_3409.jpg verschoben.
# Bild D2S_99000236.jpg verarbeitet und nach image_3410.jpg verschoben.
# Bild D2S_99000237.jpg verarbeitet und nach image_3411.jpg verschoben.
# Bild D2S_99000238.jpg verarbeitet und nach image_3412.jpg verschoben.
# Bild D2S_99000239.jpg verarbeitet und nach image_3413.jpg verschoben.
# Bild D2S_99000240.jpg verarbeitet und nach image_3414.jpg verschoben.
# Bild D2S_99000241.jpg verarbeitet und nach image_3415.jpg verschoben.
# Bild D2S_99000242.jpg verarbeitet und nach image_3416.jpg verschoben.
# Bild D2S_99000243.jpg verarbeitet und nach image_3417.jpg verschoben.
# Bild D2S_99000244.jpg verarbeitet und nach image_3418.jpg verschoben.
# Bild D2S_99000245.jpg verarbeitet und nach image_3419.jpg verschoben.
# Bild D2S_99000246.jpg verarbeitet und nach image_3420.jpg verschoben.
# Bild D2S_99000247.jpg verarbeitet und nach image_3421.jpg verschoben.
# Bild D2S_99000248.jpg verarbeitet und nach image_3422.jpg verschoben.
# Bild D2S_99000249.jpg verarbeitet und nach image_3423.jpg verschoben.
# Bild D2S_99000250.jpg verarbeitet und nach image_3424.jpg verschoben.
# Bild D2S_99000251.jpg verarbeitet und nach image_3425.jpg verschoben.
# Bild D2S_99000252.jpg verarbeitet und nach image_3426.jpg verschoben.
# Bild D2S_99000253.jpg verarbeitet und nach image_3427.jpg verschoben.
# Bild D2S_99000254.jpg verarbeitet und nach image_3428.jpg verschoben.
# Bild D2S_99000255.jpg verarbeitet und nach image_3429.jpg verschoben.
# Bild D2S_99000256.jpg verarbeitet und nach image_3430.jpg verschoben.
# Bild D2S_99000257.jpg verarbeitet und nach image_3431.jpg verschoben.
# Bild D2S_99000258.jpg verarbeitet und nach image_3432.jpg verschoben.
# Bild D2S_99000259.jpg verarbeitet und nach image_3433.jpg verschoben.
# Bild D2S_99000260.jpg verarbeitet und nach image_3434.jpg verschoben.
# Bild D2S_99000261.jpg verarbeitet und nach image_3435.jpg verschoben.
# Bild D2S_99000262.jpg verarbeitet und nach image_3436.jpg verschoben.
# Bild D2S_99000263.jpg verarbeitet und nach image_3437.jpg verschoben.
# Bild D2S_99000264.jpg verarbeitet und nach image_3438.jpg verschoben.
# Bild D2S_99000265.jpg verarbeitet und nach image_3439.jpg verschoben.
# Bild D2S_99000266.jpg verarbeitet und nach image_3440.jpg verschoben.
# Bild D2S_99000267.jpg verarbeitet und nach image_3441.jpg verschoben.
# Bild D2S_99000268.jpg verarbeitet und nach image_3442.jpg verschoben.
# Bild D2S_99000269.jpg verarbeitet und nach image_3443.jpg verschoben.
# Bild D2S_99000270.jpg verarbeitet und nach image_3444.jpg verschoben.
# Bild D2S_99000271.jpg verarbeitet und nach image_3445.jpg verschoben.
# Bild D2S_99000272.jpg verarbeitet und nach image_3446.jpg verschoben.
# Bild D2S_99000273.jpg verarbeitet und nach image_3447.jpg verschoben.
# Bild D2S_99000274.jpg verarbeitet und nach image_3448.jpg verschoben.
# Bild D2S_99000275.jpg verarbeitet und nach image_3449.jpg verschoben.
# Bild D2S_99000276.jpg verarbeitet und nach image_3450.jpg verschoben.
# Bild D2S_99000277.jpg verarbeitet und nach image_3451.jpg verschoben.
# Bild D2S_99000278.jpg verarbeitet und nach image_3452.jpg verschoben.
# Bild D2S_99000279.jpg verarbeitet und nach image_3453.jpg verschoben.
# Bild D2S_99000280.jpg verarbeitet und nach image_3454.jpg verschoben.
# Bild D2S_99000281.jpg verarbeitet und nach image_3455.jpg verschoben.
# Bild D2S_99000282.jpg verarbeitet und nach image_3456.jpg verschoben.
# Bild D2S_99000283.jpg verarbeitet und nach image_3457.jpg verschoben.
# Bild D2S_99000284.jpg verarbeitet und nach image_3458.jpg verschoben.
# Bild D2S_99000285.jpg verarbeitet und nach image_3459.jpg verschoben.
# Bild D2S_99000286.jpg verarbeitet und nach image_3460.jpg verschoben.
# Bild D2S_99000287.jpg verarbeitet und nach image_3461.jpg verschoben.
# Bild D2S_99000288.jpg verarbeitet und nach image_3462.jpg verschoben.
# Bild D2S_99000289.jpg verarbeitet und nach image_3463.jpg verschoben.
# Bild D2S_99000290.jpg verarbeitet und nach image_3464.jpg verschoben.
# Bild D2S_99000291.jpg verarbeitet und nach image_3465.jpg verschoben.
# Bild D2S_99000292.jpg verarbeitet und nach image_3466.jpg verschoben.
# Bild D2S_99000293.jpg verarbeitet und nach image_3467.jpg verschoben.
# Bild D2S_99000294.jpg verarbeitet und nach image_3468.jpg verschoben.
# Bild D2S_99000295.jpg verarbeitet und nach image_3469.jpg verschoben.
# Bild D2S_99000296.jpg verarbeitet und nach image_3470.jpg verschoben.
# Bild D2S_99000297.jpg verarbeitet und nach image_3471.jpg verschoben.
# Bild D2S_99000298.jpg verarbeitet und nach image_3472.jpg verschoben.
# Bild D2S_99000299.jpg verarbeitet und nach image_3473.jpg verschoben.
# Bild D2S_99000300.jpg verarbeitet und nach image_3474.jpg verschoben.
# Bild D2S_99000301.jpg verarbeitet und nach image_3475.jpg verschoben.
# Bild D2S_99000302.jpg verarbeitet und nach image_3476.jpg verschoben.
# Bild D2S_99000303.jpg verarbeitet und nach image_3477.jpg verschoben.
# Bild D2S_99000304.jpg verarbeitet und nach image_3478.jpg verschoben.
# Bild D2S_99000305.jpg verarbeitet und nach image_3479.jpg verschoben.
# Bild D2S_99000306.jpg verarbeitet und nach image_3480.jpg verschoben.
# Bild D2S_99000307.jpg verarbeitet und nach image_3481.jpg verschoben.
# Bild D2S_99000308.jpg verarbeitet und nach image_3482.jpg verschoben.
# Bild D2S_99000309.jpg verarbeitet und nach image_3483.jpg verschoben.
# Bild D2S_99000310.jpg verarbeitet und nach image_3484.jpg verschoben.
# Bild D2S_99000311.jpg verarbeitet und nach image_3485.jpg verschoben.
# Bild D2S_99000312.jpg verarbeitet und nach image_3486.jpg verschoben.
# Bild D2S_99000313.jpg verarbeitet und nach image_3487.jpg verschoben.
# Bild D2S_99000314.jpg verarbeitet und nach image_3488.jpg verschoben.
# Bild D2S_99000315.jpg verarbeitet und nach image_3489.jpg verschoben.
# Bild D2S_99000316.jpg verarbeitet und nach image_3490.jpg verschoben.
# Bild D2S_99000317.jpg verarbeitet und nach image_3491.jpg verschoben.
# Bild D2S_99000318.jpg verarbeitet und nach image_3492.jpg verschoben.
# Bild D2S_99000319.jpg verarbeitet und nach image_3493.jpg verschoben.
# Bild D2S_99000320.jpg verarbeitet und nach image_3494.jpg verschoben.
# Bild D2S_99000321.jpg verarbeitet und nach image_3495.jpg verschoben.
# Bild D2S_99000322.jpg verarbeitet und nach image_3496.jpg verschoben.
# Bild D2S_99000323.jpg verarbeitet und nach image_3497.jpg verschoben.
# Bild D2S_99000324.jpg verarbeitet und nach image_3498.jpg verschoben.
# Bild D2S_99000325.jpg verarbeitet und nach image_3499.jpg verschoben.
# Bild D2S_99000326.jpg verarbeitet und nach image_3500.jpg verschoben.
# Bild D2S_99000327.jpg verarbeitet und nach image_3501.jpg verschoben.
# Bild D2S_99000328.jpg verarbeitet und nach image_3502.jpg verschoben.
# Bild D2S_99000329.jpg verarbeitet und nach image_3503.jpg verschoben.
# Bild D2S_99000330.jpg verarbeitet und nach image_3504.jpg verschoben.
# Bild D2S_99000331.jpg verarbeitet und nach image_3505.jpg verschoben.
# Bild D2S_99000332.jpg verarbeitet und nach image_3506.jpg verschoben.
# Bild D2S_99000333.jpg verarbeitet und nach image_3507.jpg verschoben.
# Bild D2S_99000334.jpg verarbeitet und nach image_3508.jpg verschoben.
# Bild D2S_99000335.jpg verarbeitet und nach image_3509.jpg verschoben.
# Bild D2S_99000336.jpg verarbeitet und nach image_3510.jpg verschoben.
# Bild D2S_99000337.jpg verarbeitet und nach image_3511.jpg verschoben.
# Bild D2S_99000338.jpg verarbeitet und nach image_3512.jpg verschoben.
# Bild D2S_99000339.jpg verarbeitet und nach image_3513.jpg verschoben.
# Bild D2S_99000340.jpg verarbeitet und nach image_3514.jpg verschoben.
# Bild D2S_99000341.jpg verarbeitet und nach image_3515.jpg verschoben.
# Bild D2S_99000342.jpg verarbeitet und nach image_3516.jpg verschoben.
# Bild D2S_99000343.jpg verarbeitet und nach image_3517.jpg verschoben.
# Bild D2S_99000344.jpg verarbeitet und nach image_3518.jpg verschoben.
# Bild D2S_99000345.jpg verarbeitet und nach image_3519.jpg verschoben.
# Bild D2S_99000346.jpg verarbeitet und nach image_3520.jpg verschoben.
# Bild D2S_99000347.jpg verarbeitet und nach image_3521.jpg verschoben.
# Bild D2S_99000348.jpg verarbeitet und nach image_3522.jpg verschoben.
# Bild D2S_99000349.jpg verarbeitet und nach image_3523.jpg verschoben.
# Bild D2S_99000350.jpg verarbeitet und nach image_3524.jpg verschoben.
# Bild D2S_99000351.jpg verarbeitet und nach image_3525.jpg verschoben.
# Bild D2S_99000352.jpg verarbeitet und nach image_3526.jpg verschoben.
# Bild D2S_99000353.jpg verarbeitet und nach image_3527.jpg verschoben.
# Bild D2S_99000354.jpg verarbeitet und nach image_3528.jpg verschoben.
# Bild D2S_99000355.jpg verarbeitet und nach image_3529.jpg verschoben.
# Bild D2S_99000356.jpg verarbeitet und nach image_3530.jpg verschoben.
# Bild D2S_99000357.jpg verarbeitet und nach image_3531.jpg verschoben.
# Bild D2S_99000358.jpg verarbeitet und nach image_3532.jpg verschoben.
# Bild D2S_99000359.jpg verarbeitet und nach image_3533.jpg verschoben.
# Bild D2S_99000360.jpg verarbeitet und nach image_3534.jpg verschoben.
# Bild D2S_99000361.jpg verarbeitet und nach image_3535.jpg verschoben.
# Bild D2S_99000362.jpg verarbeitet und nach image_3536.jpg verschoben.
# Bild D2S_99000363.jpg verarbeitet und nach image_3537.jpg verschoben.
# Bild D2S_99000364.jpg verarbeitet und nach image_3538.jpg verschoben.
# Bild D2S_99000365.jpg verarbeitet und nach image_3539.jpg verschoben.
# Bild D2S_99000366.jpg verarbeitet und nach image_3540.jpg verschoben.
# Bild D2S_99000367.jpg verarbeitet und nach image_3541.jpg verschoben.
# Bild D2S_99000368.jpg verarbeitet und nach image_3542.jpg verschoben.
# Bild D2S_99000369.jpg verarbeitet und nach image_3543.jpg verschoben.
# Bild D2S_99000370.jpg verarbeitet und nach image_3544.jpg verschoben.
# Bild D2S_99000371.jpg verarbeitet und nach image_3545.jpg verschoben.
# Bild D2S_99000372.jpg verarbeitet und nach image_3546.jpg verschoben.
# Bild D2S_99000373.jpg verarbeitet und nach image_3547.jpg verschoben.
# Bild D2S_99000374.jpg verarbeitet und nach image_3548.jpg verschoben.
# Bild D2S_99000375.jpg verarbeitet und nach image_3549.jpg verschoben.
# Bild D2S_99000376.jpg verarbeitet und nach image_3550.jpg verschoben.
# Bild D2S_99000377.jpg verarbeitet und nach image_3551.jpg verschoben.
# Bild D2S_99000378.jpg verarbeitet und nach image_3552.jpg verschoben.
# Bild D2S_99000379.jpg verarbeitet und nach image_3553.jpg verschoben.
# Bild D2S_99000380.jpg verarbeitet und nach image_3554.jpg verschoben.
# Bild D2S_99000381.jpg verarbeitet und nach image_3555.jpg verschoben.
# Bild D2S_99000382.jpg verarbeitet und nach image_3556.jpg verschoben.
# Bild D2S_99000383.jpg verarbeitet und nach image_3557.jpg verschoben.
# Bild D2S_99000384.jpg verarbeitet und nach image_3558.jpg verschoben.
# Bild D2S_99000385.jpg verarbeitet und nach image_3559.jpg verschoben.
# Bild D2S_99000386.jpg verarbeitet und nach image_3560.jpg verschoben.
# Bild D2S_99000387.jpg verarbeitet und nach image_3561.jpg verschoben.
# Bild D2S_99000388.jpg verarbeitet und nach image_3562.jpg verschoben.
# Bild D2S_99000389.jpg verarbeitet und nach image_3563.jpg verschoben.
# Bild D2S_99000390.jpg verarbeitet und nach image_3564.jpg verschoben.
# Bild D2S_99000391.jpg verarbeitet und nach image_3565.jpg verschoben.
# Bild D2S_99000392.jpg verarbeitet und nach image_3566.jpg verschoben.
# Bild D2S_99000393.jpg verarbeitet und nach image_3567.jpg verschoben.
# Bild D2S_99000394.jpg verarbeitet und nach image_3568.jpg verschoben.
# Bild D2S_99000395.jpg verarbeitet und nach image_3569.jpg verschoben.
# Bild D2S_99000396.jpg verarbeitet und nach image_3570.jpg verschoben.
# Bild D2S_99000397.jpg verarbeitet und nach image_3571.jpg verschoben.
# Bild D2S_99000398.jpg verarbeitet und nach image_3572.jpg verschoben.
# Bild D2S_99000399.jpg verarbeitet und nach image_3573.jpg verschoben.
# Bild D2S_99000400.jpg verarbeitet und nach image_3574.jpg verschoben.
# Bild D2S_99000401.jpg verarbeitet und nach image_3575.jpg verschoben.
# Bild D2S_99000402.jpg verarbeitet und nach image_3576.jpg verschoben.
# Bild D2S_99000403.jpg verarbeitet und nach image_3577.jpg verschoben.
# Bild D2S_99000404.jpg verarbeitet und nach image_3578.jpg verschoben.
# Bild D2S_99000405.jpg verarbeitet und nach image_3579.jpg verschoben.
# Bild D2S_99000406.jpg verarbeitet und nach image_3580.jpg verschoben.
# Bild D2S_99000407.jpg verarbeitet und nach image_3581.jpg verschoben.
# Bild D2S_99000408.jpg verarbeitet und nach image_3582.jpg verschoben.
# Bild D2S_99000409.jpg verarbeitet und nach image_3583.jpg verschoben.
# Bild D2S_99000410.jpg verarbeitet und nach image_3584.jpg verschoben.
# Bild D2S_99000411.jpg verarbeitet und nach image_3585.jpg verschoben.
# Bild D2S_99000412.jpg verarbeitet und nach image_3586.jpg verschoben.
# Bild D2S_99000413.jpg verarbeitet und nach image_3587.jpg verschoben.
# Bild D2S_99000414.jpg verarbeitet und nach image_3588.jpg verschoben.
# Bild D2S_99000415.jpg verarbeitet und nach image_3589.jpg verschoben.
# Bild D2S_99000416.jpg verarbeitet und nach image_3590.jpg verschoben.
# Bild D2S_99000417.jpg verarbeitet und nach image_3591.jpg verschoben.
# Bild D2S_99000418.jpg verarbeitet und nach image_3592.jpg verschoben.
# Bild D2S_99000419.jpg verarbeitet und nach image_3593.jpg verschoben.
# Bild D2S_99000420.jpg verarbeitet und nach image_3594.jpg verschoben.
# Bild D2S_99000421.jpg verarbeitet und nach image_3595.jpg verschoben.
# Bild D2S_99000422.jpg verarbeitet und nach image_3596.jpg verschoben.
# Bild D2S_99000423.jpg verarbeitet und nach image_3597.jpg verschoben.
# Bild D2S_99000424.jpg verarbeitet und nach image_3598.jpg verschoben.
# Bild D2S_99000425.jpg verarbeitet und nach image_3599.jpg verschoben.
# Bild D2S_99000426.jpg verarbeitet und nach image_3600.jpg verschoben.
# Bild D2S_99000427.jpg verarbeitet und nach image_3601.jpg verschoben.
# Bild D2S_99000428.jpg verarbeitet und nach image_3602.jpg verschoben.
# Bild D2S_99000429.jpg verarbeitet und nach image_3603.jpg verschoben.
# Bild D2S_99000430.jpg verarbeitet und nach image_3604.jpg verschoben.
# Bild D2S_99000431.jpg verarbeitet und nach image_3605.jpg verschoben.
# Bild D2S_99000432.jpg verarbeitet und nach image_3606.jpg verschoben.
# Bild D2S_99000433.jpg verarbeitet und nach image_3607.jpg verschoben.
# Bild D2S_99000434.jpg verarbeitet und nach image_3608.jpg verschoben.
# Bild D2S_99000435.jpg verarbeitet und nach image_3609.jpg verschoben.
# Bild D2S_99000436.jpg verarbeitet und nach image_3610.jpg verschoben.
# Bild D2S_99000437.jpg verarbeitet und nach image_3611.jpg verschoben.
# Bild D2S_99000438.jpg verarbeitet und nach image_3612.jpg verschoben.
# Bild D2S_99000439.jpg verarbeitet und nach image_3613.jpg verschoben.
# Bild D2S_99000440.jpg verarbeitet und nach image_3614.jpg verschoben.
# Bild D2S_99000441.jpg verarbeitet und nach image_3615.jpg verschoben.
# Bild D2S_99000442.jpg verarbeitet und nach image_3616.jpg verschoben.
# Bild D2S_99000443.jpg verarbeitet und nach image_3617.jpg verschoben.
# Bild D2S_99000444.jpg verarbeitet und nach image_3618.jpg verschoben.
# Bild D2S_99000445.jpg verarbeitet und nach image_3619.jpg verschoben.
# Bild D2S_99000446.jpg verarbeitet und nach image_3620.jpg verschoben.
# Bild D2S_99000447.jpg verarbeitet und nach image_3621.jpg verschoben.
# Bild D2S_99000448.jpg verarbeitet und nach image_3622.jpg verschoben.
# Bild D2S_99000449.jpg verarbeitet und nach image_3623.jpg verschoben.
# Bild D2S_99000450.jpg verarbeitet und nach image_3624.jpg verschoben.
# Bild D2S_99000451.jpg verarbeitet und nach image_3625.jpg verschoben.
# Bild D2S_99000452.jpg verarbeitet und nach image_3626.jpg verschoben.
# Bild D2S_99000453.jpg verarbeitet und nach image_3627.jpg verschoben.
# Bild D2S_99000454.jpg verarbeitet und nach image_3628.jpg verschoben.
# Bild D2S_99000455.jpg verarbeitet und nach image_3629.jpg verschoben.
# Bild D2S_99000456.jpg verarbeitet und nach image_3630.jpg verschoben.
# Bild D2S_99000457.jpg verarbeitet und nach image_3631.jpg verschoben.
# Bild D2S_99000458.jpg verarbeitet und nach image_3632.jpg verschoben.
# Bild D2S_99000459.jpg verarbeitet und nach image_3633.jpg verschoben.
# Bild D2S_99000460.jpg verarbeitet und nach image_3634.jpg verschoben.
# Bild D2S_99000461.jpg verarbeitet und nach image_3635.jpg verschoben.
# Bild D2S_99000462.jpg verarbeitet und nach image_3636.jpg verschoben.
# Bild D2S_99000463.jpg verarbeitet und nach image_3637.jpg verschoben.
# Bild D2S_99000464.jpg verarbeitet und nach image_3638.jpg verschoben.
# Bild D2S_99000465.jpg verarbeitet und nach image_3639.jpg verschoben.
# Bild D2S_99000466.jpg verarbeitet und nach image_3640.jpg verschoben.
# Bild D2S_99000467.jpg verarbeitet und nach image_3641.jpg verschoben.
# Bild D2S_99000468.jpg verarbeitet und nach image_3642.jpg verschoben.
# Bild D2S_99000469.jpg verarbeitet und nach image_3643.jpg verschoben.
# Bild D2S_99000470.jpg verarbeitet und nach image_3644.jpg verschoben.
# Bild D2S_99000471.jpg verarbeitet und nach image_3645.jpg verschoben.
# Bild D2S_99000472.jpg verarbeitet und nach image_3646.jpg verschoben.
# Bild D2S_99000473.jpg verarbeitet und nach image_3647.jpg verschoben.
# Bild D2S_99000474.jpg verarbeitet und nach image_3648.jpg verschoben.
# Bild D2S_99000475.jpg verarbeitet und nach image_3649.jpg verschoben.
# Bild D2S_99000476.jpg verarbeitet und nach image_3650.jpg verschoben.
# Bild D2S_99000477.jpg verarbeitet und nach image_3651.jpg verschoben.
# Bild D2S_99000478.jpg verarbeitet und nach image_3652.jpg verschoben.
# Bild D2S_99000479.jpg verarbeitet und nach image_3653.jpg verschoben.
# Bild D2S_99000480.jpg verarbeitet und nach image_3654.jpg verschoben.
# Bild D2S_99000481.jpg verarbeitet und nach image_3655.jpg verschoben.
# Bild D2S_99000482.jpg verarbeitet und nach image_3656.jpg verschoben.
# Bild D2S_99000483.jpg verarbeitet und nach image_3657.jpg verschoben.
# Bild D2S_99000484.jpg verarbeitet und nach image_3658.jpg verschoben.
# Bild D2S_99000485.jpg verarbeitet und nach image_3659.jpg verschoben.
# Bild D2S_99000486.jpg verarbeitet und nach image_3660.jpg verschoben.
# Bild D2S_99000487.jpg verarbeitet und nach image_3661.jpg verschoben.
# Bild D2S_99000488.jpg verarbeitet und nach image_3662.jpg verschoben.
# Bild D2S_99000489.jpg verarbeitet und nach image_3663.jpg verschoben.
# Bild D2S_99000490.jpg verarbeitet und nach image_3664.jpg verschoben.
# Bild D2S_99000491.jpg verarbeitet und nach image_3665.jpg verschoben.
# Bild D2S_99000492.jpg verarbeitet und nach image_3666.jpg verschoben.
# Bild D2S_99000493.jpg verarbeitet und nach image_3667.jpg verschoben.
# Bild D2S_99000494.jpg verarbeitet und nach image_3668.jpg verschoben.
# Bild D2S_99000495.jpg verarbeitet und nach image_3669.jpg verschoben.
# Bild D2S_99000496.jpg verarbeitet und nach image_3670.jpg verschoben.
# Bild D2S_99000497.jpg verarbeitet und nach image_3671.jpg verschoben.
# Bild D2S_99000498.jpg verarbeitet und nach image_3672.jpg verschoben.
# Bild D2S_99000499.jpg verarbeitet und nach image_3673.jpg verschoben.
# Bild D2S_99000500.jpg verarbeitet und nach image_3674.jpg verschoben.
# Bild D2S_99000501.jpg verarbeitet und nach image_3675.jpg verschoben.
# Bild D2S_99000502.jpg verarbeitet und nach image_3676.jpg verschoben.
# Bild D2S_99000503.jpg verarbeitet und nach image_3677.jpg verschoben.
# Bild D2S_99000504.jpg verarbeitet und nach image_3678.jpg verschoben.
# Bild D2S_99000505.jpg verarbeitet und nach image_3679.jpg verschoben.
# Bild D2S_99000506.jpg verarbeitet und nach image_3680.jpg verschoben.
# Bild D2S_99000507.jpg verarbeitet und nach image_3681.jpg verschoben.
# Bild D2S_99000508.jpg verarbeitet und nach image_3682.jpg verschoben.
# Bild D2S_99000509.jpg verarbeitet und nach image_3683.jpg verschoben.
# Bild D2S_99000510.jpg verarbeitet und nach image_3684.jpg verschoben.
# Bild D2S_99000511.jpg verarbeitet und nach image_3685.jpg verschoben.
# Bild D2S_99000512.jpg verarbeitet und nach image_3686.jpg verschoben.
# Bild D2S_99000513.jpg verarbeitet und nach image_3687.jpg verschoben.
# Bild D2S_99000514.jpg verarbeitet und nach image_3688.jpg verschoben.
# Bild D2S_99000515.jpg verarbeitet und nach image_3689.jpg verschoben.
# Bild D2S_99000516.jpg verarbeitet und nach image_3690.jpg verschoben.
# Bild D2S_99000517.jpg verarbeitet und nach image_3691.jpg verschoben.
# Bild D2S_99000518.jpg verarbeitet und nach image_3692.jpg verschoben.
# Bild D2S_99000519.jpg verarbeitet und nach image_3693.jpg verschoben.
# Bild D2S_99000520.jpg verarbeitet und nach image_3694.jpg verschoben.
# Bild D2S_99000521.jpg verarbeitet und nach image_3695.jpg verschoben.
# Bild D2S_99000522.jpg verarbeitet und nach image_3696.jpg verschoben.
# Bild D2S_99000523.jpg verarbeitet und nach image_3697.jpg verschoben.
# Bild D2S_99000524.jpg verarbeitet und nach image_3698.jpg verschoben.
# Bild D2S_99000525.jpg verarbeitet und nach image_3699.jpg verschoben.
# Bild D2S_99000526.jpg verarbeitet und nach image_3700.jpg verschoben.
# Bild D2S_99000527.jpg verarbeitet und nach image_3701.jpg verschoben.
# Bild D2S_99000528.jpg verarbeitet und nach image_3702.jpg verschoben.
# Bild D2S_99000529.jpg verarbeitet und nach image_3703.jpg verschoben.
# Bild D2S_99000530.jpg verarbeitet und nach image_3704.jpg verschoben.
# Bild D2S_99000531.jpg verarbeitet und nach image_3705.jpg verschoben.
# Bild D2S_99000532.jpg verarbeitet und nach image_3706.jpg verschoben.
# Bild D2S_99000533.jpg verarbeitet und nach image_3707.jpg verschoben.
# Bild D2S_99000534.jpg verarbeitet und nach image_3708.jpg verschoben.
# Bild D2S_99000535.jpg verarbeitet und nach image_3709.jpg verschoben.
# Bild D2S_99000536.jpg verarbeitet und nach image_3710.jpg verschoben.
# Bild D2S_99000537.jpg verarbeitet und nach image_3711.jpg verschoben.
# Bild D2S_99000538.jpg verarbeitet und nach image_3712.jpg verschoben.
# Bild D2S_99000539.jpg verarbeitet und nach image_3713.jpg verschoben.
# Bild D2S_99000540.jpg verarbeitet und nach image_3714.jpg verschoben.
# Bild D2S_99000541.jpg verarbeitet und nach image_3715.jpg verschoben.
# Bild D2S_99000542.jpg verarbeitet und nach image_3716.jpg verschoben.
# Bild D2S_99000543.jpg verarbeitet und nach image_3717.jpg verschoben.
# Bild D2S_99000544.jpg verarbeitet und nach image_3718.jpg verschoben.
# Bild D2S_99000545.jpg verarbeitet und nach image_3719.jpg verschoben.
# Bild D2S_99000546.jpg verarbeitet und nach image_3720.jpg verschoben.
# Bild D2S_99000547.jpg verarbeitet und nach image_3721.jpg verschoben.
# Bild D2S_99000548.jpg verarbeitet und nach image_3722.jpg verschoben.
# Bild D2S_99000549.jpg verarbeitet und nach image_3723.jpg verschoben.
# Bild D2S_99000550.jpg verarbeitet und nach image_3724.jpg verschoben.
# Bild D2S_99000551.jpg verarbeitet und nach image_3725.jpg verschoben.
# Bild D2S_99000552.jpg verarbeitet und nach image_3726.jpg verschoben.
# Bild D2S_99000553.jpg verarbeitet und nach image_3727.jpg verschoben.
# Bild D2S_99000554.jpg verarbeitet und nach image_3728.jpg verschoben.
# Bild D2S_99000555.jpg verarbeitet und nach image_3729.jpg verschoben.
# Bild D2S_99000556.jpg verarbeitet und nach image_3730.jpg verschoben.
# Bild D2S_99000557.jpg verarbeitet und nach image_3731.jpg verschoben.
# Bild D2S_99000558.jpg verarbeitet und nach image_3732.jpg verschoben.
# Bild D2S_99000559.jpg verarbeitet und nach image_3733.jpg verschoben.
# Bild D2S_99000560.jpg verarbeitet und nach image_3734.jpg verschoben.
# Bild D2S_99000561.jpg verarbeitet und nach image_3735.jpg verschoben.
# Bild D2S_99000562.jpg verarbeitet und nach image_3736.jpg verschoben.
# Bild D2S_99000563.jpg verarbeitet und nach image_3737.jpg verschoben.
# Bild D2S_99000564.jpg verarbeitet und nach image_3738.jpg verschoben.
# Bild D2S_99000565.jpg verarbeitet und nach image_3739.jpg verschoben.
# Bild D2S_99000566.jpg verarbeitet und nach image_3740.jpg verschoben.
# Bild D2S_99000567.jpg verarbeitet und nach image_3741.jpg verschoben.
# Bild D2S_99000568.jpg verarbeitet und nach image_3742.jpg verschoben.
# Bild D2S_99000569.jpg verarbeitet und nach image_3743.jpg verschoben.
# Bild D2S_99000570.jpg verarbeitet und nach image_3744.jpg verschoben.
# Bild D2S_99000571.jpg verarbeitet und nach image_3745.jpg verschoben.
# Bild D2S_99000572.jpg verarbeitet und nach image_3746.jpg verschoben.
# Bild D2S_99000573.jpg verarbeitet und nach image_3747.jpg verschoben.
# Bild D2S_99000574.jpg verarbeitet und nach image_3748.jpg verschoben.
# Bild D2S_99000575.jpg verarbeitet und nach image_3749.jpg verschoben.
# Bild D2S_99000576.jpg verarbeitet und nach image_3750.jpg verschoben.
# Bild D2S_99000577.jpg verarbeitet und nach image_3751.jpg verschoben.
# Bild D2S_99000578.jpg verarbeitet und nach image_3752.jpg verschoben.
# Bild D2S_99000579.jpg verarbeitet und nach image_3753.jpg verschoben.
# Bild D2S_99000580.jpg verarbeitet und nach image_3754.jpg verschoben.
# Bild D2S_99000581.jpg verarbeitet und nach image_3755.jpg verschoben.
# Bild D2S_99000582.jpg verarbeitet und nach image_3756.jpg verschoben.
# Bild D2S_99000583.jpg verarbeitet und nach image_3757.jpg verschoben.
# Bild D2S_99000584.jpg verarbeitet und nach image_3758.jpg verschoben.
# Bild D2S_99000585.jpg verarbeitet und nach image_3759.jpg verschoben.
# Bild D2S_99000586.jpg verarbeitet und nach image_3760.jpg verschoben.
# Bild D2S_99000587.jpg verarbeitet und nach image_3761.jpg verschoben.
# Bild D2S_99000588.jpg verarbeitet und nach image_3762.jpg verschoben.
# Bild D2S_99000589.jpg verarbeitet und nach image_3763.jpg verschoben.
# Bild D2S_99000590.jpg verarbeitet und nach image_3764.jpg verschoben.
# Bild D2S_99000591.jpg verarbeitet und nach image_3765.jpg verschoben.
# Bild D2S_99000592.jpg verarbeitet und nach image_3766.jpg verschoben.
# Bild D2S_99000593.jpg verarbeitet und nach image_3767.jpg verschoben.
# Bild D2S_99000594.jpg verarbeitet und nach image_3768.jpg verschoben.
# Bild D2S_99000595.jpg verarbeitet und nach image_3769.jpg verschoben.
# Bild D2S_99000596.jpg verarbeitet und nach image_3770.jpg verschoben.
# Bild D2S_99000597.jpg verarbeitet und nach image_3771.jpg verschoben.
# Bild D2S_99000598.jpg verarbeitet und nach image_3772.jpg verschoben.
# Bild D2S_99000599.jpg verarbeitet und nach image_3773.jpg verschoben.
# Bild D2S_99000600.jpg verarbeitet und nach image_3774.jpg verschoben.
# Bild D2S_99000601.jpg verarbeitet und nach image_3775.jpg verschoben.
# Bild D2S_99000602.jpg verarbeitet und nach image_3776.jpg verschoben.
# Bild D2S_99000603.jpg verarbeitet und nach image_3777.jpg verschoben.
# Bild D2S_99000604.jpg verarbeitet und nach image_3778.jpg verschoben.
# Bild D2S_99000605.jpg verarbeitet und nach image_3779.jpg verschoben.
# Bild D2S_99000606.jpg verarbeitet und nach image_3780.jpg verschoben.
# Bild D2S_99000607.jpg verarbeitet und nach image_3781.jpg verschoben.
# Bild D2S_99000608.jpg verarbeitet und nach image_3782.jpg verschoben.
# Bild D2S_99000609.jpg verarbeitet und nach image_3783.jpg verschoben.
# Bild D2S_99000610.jpg verarbeitet und nach image_3784.jpg verschoben.
# Bild D2S_99000611.jpg verarbeitet und nach image_3785.jpg verschoben.
# Bild D2S_99000612.jpg verarbeitet und nach image_3786.jpg verschoben.
# Bild D2S_99000613.jpg verarbeitet und nach image_3787.jpg verschoben.
# Bild D2S_99000614.jpg verarbeitet und nach image_3788.jpg verschoben.
# Bild D2S_99000615.jpg verarbeitet und nach image_3789.jpg verschoben.
# Bild D2S_99000616.jpg verarbeitet und nach image_3790.jpg verschoben.
# Bild D2S_99000617.jpg verarbeitet und nach image_3791.jpg verschoben.
# Bild D2S_99000618.jpg verarbeitet und nach image_3792.jpg verschoben.
# Bild D2S_99000619.jpg verarbeitet und nach image_3793.jpg verschoben.
# Bild D2S_99000620.jpg verarbeitet und nach image_3794.jpg verschoben.
# Bild D2S_99000621.jpg verarbeitet und nach image_3795.jpg verschoben.
# Bild D2S_99000622.jpg verarbeitet und nach image_3796.jpg verschoben.
# Bild D2S_99000623.jpg verarbeitet und nach image_3797.jpg verschoben.
# Bild D2S_99000624.jpg verarbeitet und nach image_3798.jpg verschoben.
# Bild D2S_99000625.jpg verarbeitet und nach image_3799.jpg verschoben.
# Bild D2S_99000626.jpg verarbeitet und nach image_3800.jpg verschoben.
# Bild D2S_99000627.jpg verarbeitet und nach image_3801.jpg verschoben.
# Bild D2S_99000628.jpg verarbeitet und nach image_3802.jpg verschoben.
# Bild D2S_99000629.jpg verarbeitet und nach image_3803.jpg verschoben.
# Bild D2S_99000630.jpg verarbeitet und nach image_3804.jpg verschoben.
# Bild D2S_99000631.jpg verarbeitet und nach image_3805.jpg verschoben.
# Bild D2S_99000632.jpg verarbeitet und nach image_3806.jpg verschoben.
# Bild D2S_99000633.jpg verarbeitet und nach image_3807.jpg verschoben.
# Bild D2S_99000634.jpg verarbeitet und nach image_3808.jpg verschoben.
# Bild D2S_99000635.jpg verarbeitet und nach image_3809.jpg verschoben.
# Bild D2S_99000636.jpg verarbeitet und nach image_3810.jpg verschoben.
# Bild D2S_99000637.jpg verarbeitet und nach image_3811.jpg verschoben.
# Bild D2S_99000638.jpg verarbeitet und nach image_3812.jpg verschoben.
# Bild D2S_99000639.jpg verarbeitet und nach image_3813.jpg verschoben.
# Bild D2S_99000640.jpg verarbeitet und nach image_3814.jpg verschoben.
# Bild D2S_99000641.jpg verarbeitet und nach image_3815.jpg verschoben.
# Bild D2S_99000642.jpg verarbeitet und nach image_3816.jpg verschoben.
# Bild D2S_99000643.jpg verarbeitet und nach image_3817.jpg verschoben.
# Bild D2S_99000644.jpg verarbeitet und nach image_3818.jpg verschoben.
# Bild D2S_99000645.jpg verarbeitet und nach image_3819.jpg verschoben.
# Bild D2S_99000646.jpg verarbeitet und nach image_3820.jpg verschoben.
# Bild D2S_99000647.jpg verarbeitet und nach image_3821.jpg verschoben.
# Bild D2S_99000648.jpg verarbeitet und nach image_3822.jpg verschoben.
# Bild D2S_99000649.jpg verarbeitet und nach image_3823.jpg verschoben.
# Bild D2S_99000650.jpg verarbeitet und nach image_3824.jpg verschoben.
# Bild D2S_99000651.jpg verarbeitet und nach image_3825.jpg verschoben.
# Bild D2S_99000652.jpg verarbeitet und nach image_3826.jpg verschoben.
# Bild D2S_99000653.jpg verarbeitet und nach image_3827.jpg verschoben.
# Bild D2S_99000654.jpg verarbeitet und nach image_3828.jpg verschoben.
# Bild D2S_99000655.jpg verarbeitet und nach image_3829.jpg verschoben.
# Bild D2S_99000656.jpg verarbeitet und nach image_3830.jpg verschoben.
# Bild D2S_99000657.jpg verarbeitet und nach image_3831.jpg verschoben.
# Bild D2S_99000658.jpg verarbeitet und nach image_3832.jpg verschoben.
# Bild D2S_99000659.jpg verarbeitet und nach image_3833.jpg verschoben.
# Bild D2S_99000660.jpg verarbeitet und nach image_3834.jpg verschoben.
# Bild D2S_99000661.jpg verarbeitet und nach image_3835.jpg verschoben.
# Bild D2S_99000662.jpg verarbeitet und nach image_3836.jpg verschoben.
# Bild D2S_99000663.jpg verarbeitet und nach image_3837.jpg verschoben.
# Bild D2S_99000664.jpg verarbeitet und nach image_3838.jpg verschoben.
# Bild D2S_99000665.jpg verarbeitet und nach image_3839.jpg verschoben.
# Bild D2S_99000666.jpg verarbeitet und nach image_3840.jpg verschoben.
# Bild D2S_99000667.jpg verarbeitet und nach image_3841.jpg verschoben.
# Bild D2S_99000668.jpg verarbeitet und nach image_3842.jpg verschoben.
# Bild D2S_99000669.jpg verarbeitet und nach image_3843.jpg verschoben.
# Bild D2S_99000670.jpg verarbeitet und nach image_3844.jpg verschoben.
# Bild D2S_99000671.jpg verarbeitet und nach image_3845.jpg verschoben.
# Bild D2S_99000672.jpg verarbeitet und nach image_3846.jpg verschoben.
# Bild D2S_99000673.jpg verarbeitet und nach image_3847.jpg verschoben.
# Bild D2S_99000674.jpg verarbeitet und nach image_3848.jpg verschoben.
# Bild D2S_99000675.jpg verarbeitet und nach image_3849.jpg verschoben.
# Bild D2S_99000676.jpg verarbeitet und nach image_3850.jpg verschoben.
# Bild D2S_99000677.jpg verarbeitet und nach image_3851.jpg verschoben.
# Bild D2S_99000678.jpg verarbeitet und nach image_3852.jpg verschoben.
# Bild D2S_99000679.jpg verarbeitet und nach image_3853.jpg verschoben.
# Bild D2S_99000680.jpg verarbeitet und nach image_3854.jpg verschoben.
# Bild D2S_99000681.jpg verarbeitet und nach image_3855.jpg verschoben.
# Bild D2S_99000682.jpg verarbeitet und nach image_3856.jpg verschoben.
# Bild D2S_99000683.jpg verarbeitet und nach image_3857.jpg verschoben.
# Bild D2S_99000684.jpg verarbeitet und nach image_3858.jpg verschoben.
# ...
# Bild D2S_067009.jpg verarbeitet und nach image_20923.jpg verschoben.
# Bild D2S_067010.jpg verarbeitet und nach image_20924.jpg verschoben.
# Bild D2S_067011.jpg verarbeitet und nach image_20925.jpg verschoben.
# Bild D2S_067012.jpg verarbeitet und nach image_20926.jpg verschoben.
# Bild D2S_067013.jpg verarbeitet und nach image_20927.jpg verschoben.
# Bild D2S_067014.jpg verarbeitet und nach image_20928.jpg verschoben.
# Bild D2S_067015.jpg verarbeitet und nach image_20929.jpg verschoben.
# Bild D2S_067016.jpg verarbeitet und nach image_20930.jpg verschoben.
# Bild D2S_067017.jpg verarbeitet und nach image_20931.jpg verschoben.
# Bild D2S_067018.jpg verarbeitet und nach image_20932.jpg verschoben.
# Bild D2S_067019.jpg verarbeitet und nach image_20933.jpg verschoben.
# Bild D2S_067020.jpg verarbeitet und nach image_20934.jpg verschoben.
# Bild D2S_067021.jpg verarbeitet und nach image_20935.jpg verschoben.
# Bild D2S_067022.jpg verarbeitet und nach image_20936.jpg verschoben.
# Bild D2S_067023.jpg verarbeitet und nach image_20937.jpg verschoben.
# Bild D2S_067024.jpg verarbeitet und nach image_20938.jpg verschoben.
# Bild D2S_067025.jpg verarbeitet und nach image_20939.jpg verschoben.
# Bild D2S_067026.jpg verarbeitet und nach image_20940.jpg verschoben.
# Bild D2S_067027.jpg verarbeitet und nach image_20941.jpg verschoben.
# Bild D2S_067028.jpg verarbeitet und nach image_20942.jpg verschoben.
# Bild D2S_067029.jpg verarbeitet und nach image_20943.jpg verschoben.
# Bild D2S_068000.jpg verarbeitet und nach image_20944.jpg verschoben.
# Bild D2S_068001.jpg verarbeitet und nach image_20945.jpg verschoben.
# Bild D2S_068002.jpg verarbeitet und nach image_20946.jpg verschoben.
# Bild D2S_068003.jpg verarbeitet und nach image_20947.jpg verschoben.
# Bild D2S_068004.jpg verarbeitet und nach image_20948.jpg verschoben.
# Bild D2S_068005.jpg verarbeitet und nach image_20949.jpg verschoben.
# Bild D2S_068006.jpg verarbeitet und nach image_20950.jpg verschoben.
# Bild D2S_068007.jpg verarbeitet und nach image_20951.jpg verschoben.
# Bild D2S_068008.jpg verarbeitet und nach image_20952.jpg verschoben.
# Bild D2S_068009.jpg verarbeitet und nach image_20953.jpg verschoben.
# Bild D2S_068010.jpg verarbeitet und nach image_20954.jpg verschoben.
# Bild D2S_068011.jpg verarbeitet und nach image_20955.jpg verschoben.
# Bild D2S_068012.jpg verarbeitet und nach image_20956.jpg verschoben.
# Bild D2S_068013.jpg verarbeitet und nach image_20957.jpg verschoben.
# Bild D2S_068014.jpg verarbeitet und nach image_20958.jpg verschoben.
# Bild D2S_068015.jpg verarbeitet und nach image_20959.jpg verschoben.
# Bild D2S_068016.jpg verarbeitet und nach image_20960.jpg verschoben.
# Bild D2S_068017.jpg verarbeitet und nach image_20961.jpg verschoben.
# Bild D2S_068018.jpg verarbeitet und nach image_20962.jpg verschoben.
# Bild D2S_068019.jpg verarbeitet und nach image_20963.jpg verschoben.
# Bild D2S_068020.jpg verarbeitet und nach image_20964.jpg verschoben.
# Bild D2S_068021.jpg verarbeitet und nach image_20965.jpg verschoben.
# Bild D2S_068022.jpg verarbeitet und nach image_20966.jpg verschoben.
# Bild D2S_068023.jpg verarbeitet und nach image_20967.jpg verschoben.
# Bild D2S_068024.jpg verarbeitet und nach image_20968.jpg verschoben.
# Bild D2S_068025.jpg verarbeitet und nach image_20969.jpg verschoben.
# Bild D2S_068026.jpg verarbeitet und nach image_20970.jpg verschoben.
# Bild D2S_068027.jpg verarbeitet und nach image_20971.jpg verschoben.
# Bild D2S_068028.jpg verarbeitet und nach image_20972.jpg verschoben.
# Bild D2S_068029.jpg verarbeitet und nach image_20973.jpg verschoben.
# Bild D2S_068100.jpg verarbeitet und nach image_20974.jpg verschoben.
# Bild D2S_068101.jpg verarbeitet und nach image_20975.jpg verschoben.
# Bild D2S_068102.jpg verarbeitet und nach image_20976.jpg verschoben.
# Bild D2S_068103.jpg verarbeitet und nach image_20977.jpg verschoben.
# Bild D2S_068104.jpg verarbeitet und nach image_20978.jpg verschoben.
# Bild D2S_068105.jpg verarbeitet und nach image_20979.jpg verschoben.
# Bild D2S_068106.jpg verarbeitet und nach image_20980.jpg verschoben.
# Bild D2S_068107.jpg verarbeitet und nach image_20981.jpg verschoben.
# Bild D2S_068108.jpg verarbeitet und nach image_20982.jpg verschoben.
# Bild D2S_068109.jpg verarbeitet und nach image_20983.jpg verschoben.
# Bild D2S_068110.jpg verarbeitet und nach image_20984.jpg verschoben.
# Bild D2S_068111.jpg verarbeitet und nach image_20985.jpg verschoben.
# Bild D2S_068112.jpg verarbeitet und nach image_20986.jpg verschoben.
# Bild D2S_068113.jpg verarbeitet und nach image_20987.jpg verschoben.
# Bild D2S_068114.jpg verarbeitet und nach image_20988.jpg verschoben.
# Bild D2S_068115.jpg verarbeitet und nach image_20989.jpg verschoben.
# Bild D2S_068116.jpg verarbeitet und nach image_20990.jpg verschoben.
# Bild D2S_068117.jpg verarbeitet und nach image_20991.jpg verschoben.
# Bild D2S_068118.jpg verarbeitet und nach image_20992.jpg verschoben.
# Bild D2S_068119.jpg verarbeitet und nach image_20993.jpg verschoben.
# Bild D2S_068120.jpg verarbeitet und nach image_20994.jpg verschoben.
# Bild D2S_068121.jpg verarbeitet und nach image_20995.jpg verschoben.
# Bild D2S_068122.jpg verarbeitet und nach image_20996.jpg verschoben.
# Bild D2S_068123.jpg verarbeitet und nach image_20997.jpg verschoben.
# Bild D2S_068124.jpg verarbeitet und nach image_20998.jpg verschoben.
# Bild D2S_068125.jpg verarbeitet und nach image_20999.jpg verschoben.
# Bild D2S_068126.jpg verarbeitet und nach image_21000.jpg verschoben.
# Bild D2S_068127.jpg verarbeitet und nach image_21001.jpg verschoben.
# Bild D2S_068128.jpg verarbeitet und nach image_21002.jpg verschoben.
# Bild D2S_068129.jpg verarbeitet und nach image_21003.jpg verschoben.
# Bild D2S_068200.jpg verarbeitet und nach image_21004.jpg verschoben.
# Bild D2S_068201.jpg verarbeitet und nach image_21005.jpg verschoben.
# Bild D2S_068202.jpg verarbeitet und nach image_21006.jpg verschoben.
# Bild D2S_068203.jpg verarbeitet und nach image_21007.jpg verschoben.
# Bild D2S_068204.jpg verarbeitet und nach image_21008.jpg verschoben.
# Bild D2S_068205.jpg verarbeitet und nach image_21009.jpg verschoben.
# Bild D2S_068206.jpg verarbeitet und nach image_21010.jpg verschoben.
# Bild D2S_068207.jpg verarbeitet und nach image_21011.jpg verschoben.
# Bild D2S_068208.jpg verarbeitet und nach image_21012.jpg verschoben.
# Bild D2S_068209.jpg verarbeitet und nach image_21013.jpg verschoben.
# Bild D2S_068210.jpg verarbeitet und nach image_21014.jpg verschoben.
# Bild D2S_068211.jpg verarbeitet und nach image_21015.jpg verschoben.
# Bild D2S_068212.jpg verarbeitet und nach image_21016.jpg verschoben.
# Bild D2S_068213.jpg verarbeitet und nach image_21017.jpg verschoben.
# Bild D2S_068214.jpg verarbeitet und nach image_21018.jpg verschoben.
# Bild D2S_068215.jpg verarbeitet und nach image_21019.jpg verschoben.
# Bild D2S_068216.jpg verarbeitet und nach image_21020.jpg verschoben.
# Bild D2S_068217.jpg verarbeitet und nach image_21021.jpg verschoben.
# Bild D2S_068218.jpg verarbeitet und nach image_21022.jpg verschoben.
# Bild D2S_068219.jpg verarbeitet und nach image_21023.jpg verschoben.
# Bild D2S_068220.jpg verarbeitet und nach image_21024.jpg verschoben.
# Bild D2S_068221.jpg verarbeitet und nach image_21025.jpg verschoben.
# Bild D2S_068222.jpg verarbeitet und nach image_21026.jpg verschoben.
# Bild D2S_068223.jpg verarbeitet und nach image_21027.jpg verschoben.
# Bild D2S_068224.jpg verarbeitet und nach image_21028.jpg verschoben.
# Bild D2S_068225.jpg verarbeitet und nach image_21029.jpg verschoben.
# Bild D2S_068226.jpg verarbeitet und nach image_21030.jpg verschoben.
# Bild D2S_068227.jpg verarbeitet und nach image_21031.jpg verschoben.
# Bild D2S_068228.jpg verarbeitet und nach image_21032.jpg verschoben.
# Bild D2S_068229.jpg verarbeitet und nach image_21033.jpg verschoben.
# Bild D2S_068300.jpg verarbeitet und nach image_21034.jpg verschoben.
# Bild D2S_068301.jpg verarbeitet und nach image_21035.jpg verschoben.
# Bild D2S_068302.jpg verarbeitet und nach image_21036.jpg verschoben.
# Bild D2S_068303.jpg verarbeitet und nach image_21037.jpg verschoben.
# Bild D2S_068304.jpg verarbeitet und nach image_21038.jpg verschoben.
# Bild D2S_068305.jpg verarbeitet und nach image_21039.jpg verschoben.
# Bild D2S_068306.jpg verarbeitet und nach image_21040.jpg verschoben.
# Bild D2S_068307.jpg verarbeitet und nach image_21041.jpg verschoben.
# Bild D2S_068308.jpg verarbeitet und nach image_21042.jpg verschoben.
# Bild D2S_068309.jpg verarbeitet und nach image_21043.jpg verschoben.
# Bild D2S_068310.jpg verarbeitet und nach image_21044.jpg verschoben.
# Bild D2S_068311.jpg verarbeitet und nach image_21045.jpg verschoben.
# Bild D2S_068312.jpg verarbeitet und nach image_21046.jpg verschoben.
# Bild D2S_068313.jpg verarbeitet und nach image_21047.jpg verschoben.
# Bild D2S_068314.jpg verarbeitet und nach image_21048.jpg verschoben.
# Bild D2S_068315.jpg verarbeitet und nach image_21049.jpg verschoben.
# Bild D2S_068316.jpg verarbeitet und nach image_21050.jpg verschoben.
# Bild D2S_068317.jpg verarbeitet und nach image_21051.jpg verschoben.
# Bild D2S_068318.jpg verarbeitet und nach image_21052.jpg verschoben.
# Bild D2S_068319.jpg verarbeitet und nach image_21053.jpg verschoben.
# Bild D2S_068320.jpg verarbeitet und nach image_21054.jpg verschoben.
# Bild D2S_068321.jpg verarbeitet und nach image_21055.jpg verschoben.
# Bild D2S_068322.jpg verarbeitet und nach image_21056.jpg verschoben.
# Bild D2S_068323.jpg verarbeitet und nach image_21057.jpg verschoben.
# Bild D2S_068324.jpg verarbeitet und nach image_21058.jpg verschoben.
# Bild D2S_068325.jpg verarbeitet und nach image_21059.jpg verschoben.
# Bild D2S_068326.jpg verarbeitet und nach image_21060.jpg verschoben.
# Bild D2S_068327.jpg verarbeitet und nach image_21061.jpg verschoben.
# Bild D2S_068328.jpg verarbeitet und nach image_21062.jpg verschoben.
# Bild D2S_068329.jpg verarbeitet und nach image_21063.jpg verschoben.
# Bild D2S_068400.jpg verarbeitet und nach image_21064.jpg verschoben.
# Bild D2S_068401.jpg verarbeitet und nach image_21065.jpg verschoben.
# Bild D2S_068402.jpg verarbeitet und nach image_21066.jpg verschoben.
# Bild D2S_068403.jpg verarbeitet und nach image_21067.jpg verschoben.
# Bild D2S_068404.jpg verarbeitet und nach image_21068.jpg verschoben.
# Bild D2S_068405.jpg verarbeitet und nach image_21069.jpg verschoben.
# Bild D2S_068406.jpg verarbeitet und nach image_21070.jpg verschoben.
# Bild D2S_068407.jpg verarbeitet und nach image_21071.jpg verschoben.
# Bild D2S_068408.jpg verarbeitet und nach image_21072.jpg verschoben.
# Bild D2S_068409.jpg verarbeitet und nach image_21073.jpg verschoben.
# Bild D2S_068410.jpg verarbeitet und nach image_21074.jpg verschoben.
# Bild D2S_068411.jpg verarbeitet und nach image_21075.jpg verschoben.
# Bild D2S_068412.jpg verarbeitet und nach image_21076.jpg verschoben.
# Bild D2S_068413.jpg verarbeitet und nach image_21077.jpg verschoben.
# Bild D2S_068414.jpg verarbeitet und nach image_21078.jpg verschoben.
# Bild D2S_068415.jpg verarbeitet und nach image_21079.jpg verschoben.
# Bild D2S_068416.jpg verarbeitet und nach image_21080.jpg verschoben.
# Bild D2S_068417.jpg verarbeitet und nach image_21081.jpg verschoben.
# Bild D2S_068418.jpg verarbeitet und nach image_21082.jpg verschoben.
# Bild D2S_068419.jpg verarbeitet und nach image_21083.jpg verschoben.
# Bild D2S_068420.jpg verarbeitet und nach image_21084.jpg verschoben.
# Bild D2S_068421.jpg verarbeitet und nach image_21085.jpg verschoben.
# Bild D2S_068422.jpg verarbeitet und nach image_21086.jpg verschoben.
# Bild D2S_068423.jpg verarbeitet und nach image_21087.jpg verschoben.
# Bild D2S_068424.jpg verarbeitet und nach image_21088.jpg verschoben.
# Bild D2S_068425.jpg verarbeitet und nach image_21089.jpg verschoben.
# Bild D2S_068426.jpg verarbeitet und nach image_21090.jpg verschoben.
# Bild D2S_068427.jpg verarbeitet und nach image_21091.jpg verschoben.
# Bild D2S_068428.jpg verarbeitet und nach image_21092.jpg verschoben.
# Bild D2S_068429.jpg verarbeitet und nach image_21093.jpg verschoben.
# Bild D2S_069700.jpg verarbeitet und nach image_21094.jpg verschoben.
# Bild D2S_069701.jpg verarbeitet und nach image_21095.jpg verschoben.
# Bild D2S_069702.jpg verarbeitet und nach image_21096.jpg verschoben.
# Bild D2S_069703.jpg verarbeitet und nach image_21097.jpg verschoben.
# Bild D2S_069704.jpg verarbeitet und nach image_21098.jpg verschoben.
# Bild D2S_069705.jpg verarbeitet und nach image_21099.jpg verschoben.
# Bild D2S_069706.jpg verarbeitet und nach image_21100.jpg verschoben.
# Bild D2S_069707.jpg verarbeitet und nach image_21101.jpg verschoben.
# Bild D2S_069708.jpg verarbeitet und nach image_21102.jpg verschoben.
# Bild D2S_069709.jpg verarbeitet und nach image_21103.jpg verschoben.
# Bild D2S_069710.jpg verarbeitet und nach image_21104.jpg verschoben.
# Bild D2S_069711.jpg verarbeitet und nach image_21105.jpg verschoben.
# Bild D2S_069712.jpg verarbeitet und nach image_21106.jpg verschoben.
# Bild D2S_069713.jpg verarbeitet und nach image_21107.jpg verschoben.
# Bild D2S_069714.jpg verarbeitet und nach image_21108.jpg verschoben.
# Bild D2S_069715.jpg verarbeitet und nach image_21109.jpg verschoben.
# Bild D2S_069716.jpg verarbeitet und nach image_21110.jpg verschoben.
# Bild D2S_069717.jpg verarbeitet und nach image_21111.jpg verschoben.
# Bild D2S_069718.jpg verarbeitet und nach image_21112.jpg verschoben.
# Bild D2S_069719.jpg verarbeitet und nach image_21113.jpg verschoben.
# Bild D2S_069720.jpg verarbeitet und nach image_21114.jpg verschoben.
# Bild D2S_069721.jpg verarbeitet und nach image_21115.jpg verschoben.
# Bild D2S_069722.jpg verarbeitet und nach image_21116.jpg verschoben.
# Bild D2S_069723.jpg verarbeitet und nach image_21117.jpg verschoben.
# Bild D2S_069724.jpg verarbeitet und nach image_21118.jpg verschoben.
# Bild D2S_069725.jpg verarbeitet und nach image_21119.jpg verschoben.
# Bild D2S_069726.jpg verarbeitet und nach image_21120.jpg verschoben.
# Bild D2S_069727.jpg verarbeitet und nach image_21121.jpg verschoben.
# Bild D2S_069728.jpg verarbeitet und nach image_21122.jpg verschoben.
# Bild D2S_069729.jpg verarbeitet und nach image_21123.jpg verschoben.
# Bild D2S_070000.jpg verarbeitet und nach image_21124.jpg verschoben.
# Bild D2S_070001.jpg verarbeitet und nach image_21125.jpg verschoben.
# Bild D2S_070002.jpg verarbeitet und nach image_21126.jpg verschoben.
# Bild D2S_070003.jpg verarbeitet und nach image_21127.jpg verschoben.
# Bild D2S_070004.jpg verarbeitet und nach image_21128.jpg verschoben.
# Bild D2S_070005.jpg verarbeitet und nach image_21129.jpg verschoben.
# Bild D2S_070006.jpg verarbeitet und nach image_21130.jpg verschoben.
# Bild D2S_070007.jpg verarbeitet und nach image_21131.jpg verschoben.
# Bild D2S_070008.jpg verarbeitet und nach image_21132.jpg verschoben.
# Bild D2S_070009.jpg verarbeitet und nach image_21133.jpg verschoben.
# Bild D2S_070010.jpg verarbeitet und nach image_21134.jpg verschoben.
# Bild D2S_070011.jpg verarbeitet und nach image_21135.jpg verschoben.
# Bild D2S_070012.jpg verarbeitet und nach image_21136.jpg verschoben.
# Bild D2S_070013.jpg verarbeitet und nach image_21137.jpg verschoben.
# Bild D2S_070014.jpg verarbeitet und nach image_21138.jpg verschoben.
# Bild D2S_070015.jpg verarbeitet und nach image_21139.jpg verschoben.
# Bild D2S_070016.jpg verarbeitet und nach image_21140.jpg verschoben.
# Bild D2S_070017.jpg verarbeitet und nach image_21141.jpg verschoben.
# Bild D2S_070018.jpg verarbeitet und nach image_21142.jpg verschoben.
# Bild D2S_070019.jpg verarbeitet und nach image_21143.jpg verschoben.
# Bild D2S_070020.jpg verarbeitet und nach image_21144.jpg verschoben.
# Bild D2S_070021.jpg verarbeitet und nach image_21145.jpg verschoben.
# Bild D2S_070022.jpg verarbeitet und nach image_21146.jpg verschoben.
# Bild D2S_070023.jpg verarbeitet und nach image_21147.jpg verschoben.
# Bild D2S_070024.jpg verarbeitet und nach image_21148.jpg verschoben.
# Bild D2S_070025.jpg verarbeitet und nach image_21149.jpg verschoben.
# Bild D2S_070026.jpg verarbeitet und nach image_21150.jpg verschoben.
# Bild D2S_070027.jpg verarbeitet und nach image_21151.jpg verschoben.
# Bild D2S_070028.jpg verarbeitet und nach image_21152.jpg verschoben.
# Bild D2S_070029.jpg verarbeitet und nach image_21153.jpg verschoben.

# %%
import json

def count_images_with_annotations(annotation_path):
    with open(annotation_path, 'r') as f:
        coco_data = json.load(f)
    
    # Extrahiere alle Annotationen und Bilder
    annotations = coco_data.get("annotations", [])
    images = coco_data.get("images", [])
    
    # Setze die Bild-IDs aus den Annotationen
    annotated_image_ids = {annotation["image_id"] for annotation in annotations}
    
    # Zähle die Bilder, die eine Annotation haben
    count = sum(1 for image in images if image["id"] in annotated_image_ids)
    
    return count

# Beispiel-Aufruf
dataset_labels = "../MIT-Dataset/annotations/"
for subfolder in os.listdir(dataset_labels):
    path_to_labels = os.path.join(dataset_labels, subfolder)
    num_images_with_annotations = count_images_with_annotations(path_to_labels)
    print(f"Anzahl der Bilder mit Annotationen in {path_to_labels}: {num_images_with_annotations}")
# Out:
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_augmented.json: 10000
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_test_info.json: 0
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_test_info_clutter.json: 0
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_test_info_occlusion.json: 0
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_test_info_random_background.json: 0
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_test_info_random_background_wo_clutter.json: 0
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_test_info_wo_occlusion.json: 0
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_training.json: 4380
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_training_light0.json: 1460
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_training_rot0.json: 438
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_training_rot0_light0.json: 146
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_validation.json: 3600
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_validation_clutter.json: 540
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_validation_occlusion.json: 990
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_validation_random_background.json: 1350
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_validation_random_background_wo_clutter.json: 810
# Anzahl der Bilder mit Annotationen in ../MIT-Dataset/annotations/D2S_validation_wo_occlusion.json: 660

# %%
import os
import ast

# Dictionary
price_id_dict = {
    39: ['cereals', 2.49], 40: ['packaged cereal bars', 1.99], 41: ['salad', 2.29],
    42: ['canned soft drink', 0.99], 43: ['board eraser', 4.99], 44: ['pears', 0.67],
    45: ['kiwis', 0.29], 46: ['orange citrus', 0.29], 47: ['zucchinis', 1.11],
    48: ['cucumbers', 1.11], 49: ['carrots', 0.19], 50: ['apple spritzer', 1.19],
    51: ['coca cola', 1.10], 52: ['brown glass', 1.29], 53: ['ink cartridge', 4.99],
    54: ['water_small', 0.79], 55: ['water_big', 1.19], 56: ['tomatos', 1.49],
    57: ['apple bundle', 1.19], 58: ['orange bundle', 1.29], 59: ['grapes bundle', 1.49],
    60: ['lose Riegel', 0.69], 61: ['cacao', 4.99], 26: ['tea', 2.35],
    9: ['pasta', 2.69], 3: ['avocados', 1.29], 4: ['bananas', 0.46],
    1: ['apples', 0.6], 13: ['coffee', 7.99]
}

# File path
path = "../Dataset/prices.txt"
name = "MITec: "

# Schreiben in die Datei
if os.path.exists(path):
    with open(path, "a") as f:  # "a" zum Anhängen
        f.write(f"{name}{price_id_dict}\n")
else:
    with open(path, "w") as f:  # "w" zum Erstellen und Schreiben
        f.write(f"{name}{price_id_dict}\n")
